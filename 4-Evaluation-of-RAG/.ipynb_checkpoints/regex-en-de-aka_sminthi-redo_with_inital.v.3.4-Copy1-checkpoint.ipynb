# %% [raw]
# 25.07.24 msd4: okay, model gut, neues template gut, glaub template war von lama welches i ch in rag-expanded_v1.1 genommen habe nice
# values mit rag gepullt und mit regex
#
# 31.07: jetzt mal die bad and good ones testen
#
#
# 02.08. only 1 pain from triage, since local llm generation only used pain in second_act
#
#
# 05.08. jetz noch die initial

# %%
import os
import json
import pandas as pd
import re
from pymongo import MongoClient
from bson import ObjectId


def create_all_results_json():
    directory = os.getcwd()  # Get the current working directory
    output_file = os.path.join(directory, 'all_results.json')

    def read_json_files(directory):
        results = []
        seen_ids = set()  # To keep track of unique entries based on '_id'

        # Loop through all files in the directory
        for filename in os.listdir(directory):
            if filename.startswith("r_") and filename.endswith(".json"):
                filepath = os.path.join(directory, filename)
                with open(filepath, 'r', encoding='utf-8') as file:
                    try:
                        data = json.load(file)
                        if isinstance(data, dict):  # In case the data is a single dictionary
                            data = [data]
                        # Ensure unique entries based on '_id'
                        for entry in data:
                            if isinstance(entry, dict):  # Ensure each entry is a dictionary
                                _id = entry.get('_id')
                                if _id and _id not in seen_ids:
                                    seen_ids.add(_id)
                                    results.append(entry)
                    except json.JSONDecodeError:
                        print(f"Error decoding JSON from file: {filepath}")

        return results

    def save_to_json(data, output_file):
        with open(output_file, 'w', encoding='utf-8') as file:
            json.dump(data, file, ensure_ascii=False, indent=4)

    # Read the JSON files and combine the results
    combined_results = read_json_files(directory)

    # Save the combined results to a single JSON file
    save_to_json(combined_results, output_file)

    print(f"Combined results saved to {output_file}")

# Usage example to create all_results.json
create_all_results_json()
# Out:
# Combined results saved to /home/msd4/aidocsMosi/git_dev_bench_fix/AIDoCS-DataGeneration/6_Benchmarking-Finalpaper/4-Evaluation-of-RAG/all_results.json

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def load_all_results_json():
    directory = os.getcwd()  # Get the current working directory
    file_path = os.path.join(directory, 'all_results.json')
    input_json = None

    # Check if the file exists
    if os.path.exists(file_path):
        print("File exists. Proceeding to load.")
        # Load the JSON file
        try:
            with open(file_path, 'r', encoding='utf-8') as file:
                input_json = json.load(file)
            print("File loaded successfully.")
        except json.JSONDecodeError:
            print("Error decoding JSON file.")
    else:
        print(f"File not found: {file_path}")
    
    return input_json

# Usage example to load all_results.json
input_json = load_all_results_json()

# Optionally print the loaded JSON content to verify
# print(json.dumps(input_json, indent=2))
# Out:
# File exists. Proceeding to load.
# File loaded successfully.

# %%
question_data_mapping = {
    "chiefcomplaint":      {"collection": "ED-Triage-prammed", "field": "chiefcomplaint"},
    "medication_reported": {"collection": "ED-Medrecon-prammed", "field": "name"},
    "medication_pyxis":    {"collection": "ED-Pyxis-prammed", "field": "name"},
    "diagnosis":           {"collection": "ED-Diagnosis-prammed", "field": "icd_title"},
    "bp":                  {"collection": ["ED-Triage-prammed", "ED-VitalSigns-prammed"], "fields": [("sbp", "dbp")], "format": "triage: {0} {1}; vitals: {2} {3}"},
    "heartrate":           {"collection": ["ED-Triage-prammed", "ED-VitalSigns-prammed"], "fields": ["heartrate"], "format": "triage: {0}; vitals: {1}"},
    "o2sat_triage":        {"collection": ["ED-Triage-prammed", "ED-VitalSigns-prammed"], "fields": ["o2sat"], "format": "triage: {0}; vitals: {1}"},
    "resprate":            {"collection": ["ED-Triage-prammed", "ED-VitalSigns-prammed"], "fields": ["resprate"], "format": "triage: {0}; vitals: {1}"},
    "temperature":         {"collection": ["ED-Triage-prammed", "ED-VitalSigns-prammed"], "fields": ["temperature"], "format": "triage: {0}; vitals: {1}"},
    "pain_triage":         {"collection": ["ED-Triage-prammed"], "fields": ["pain"], "format": "triage: {0}"}
}

# %%
# Other questions of interest
nominal_questions = [
    "chiefcomplaint",
    "medication_reported",
    "medication_pyxis",
    "diagnosis"
]

# %%
import pandas as pd
import json
import os

def create_basic_dataframe(input_json):
    rows = []

    for i, record in enumerate(input_json):
        record_id = record.get('_id', '')
        
        for question, answer in record['answers'].items():
            rows.append([i, record_id, question, answer, ''])
    
    df_basic = pd.DataFrame(rows, columns=['json_i', '_id', 'question', 'answer', 'data'])
    return df_basic

# Usage example

df_basic = create_basic_dataframe(input_json)
df_basic.head(1)
# Out:
#    json_i                       _id        question  \
# 0       0  669933e4afbfd9c3c2d8efd0  chiefcomplaint
#
#                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
#
#   data
# 0

# %%
df_basic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   json_i    990 non-null    int64
#  1   _id       990 non-null    object
#  2   question  990 non-null    object
#  3   answer    990 non-null    object
#  4   data      990 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 38.8+ KB

# %% [raw]
# def remove_rows_by_id(df, ids_to_remove):
#     """
#     Removes rows from a DataFrame based on a list of _id values.
#
#     :param df: The original DataFrame.
#     :param ids_to_remove: A list of _id values to remove from the DataFrame.
#     :return: A new DataFrame with the specified rows removed.
#     """
#     # Convert the list of ids to remove into a set for faster lookup
#     ids_to_remove_set = set(ids_to_remove)
#
#     # Filter the DataFrame to exclude rows with _id values in the set
#     filtered_df = df[~df['_id'].isin(ids_to_remove_set)]
#     return filtered_df
#
#
# '''
# # Example DataFrame creation (assuming you have it loaded similarly)
# data = {
#     'stay_id': [
#         32126227, 36292453, 35382782, 34401029, 35678991, 31198145,
#         36208077, 30394981, 34392346, 34817775, 35718136, 39476258,
#         32292711, 36776235, 32234793, 35618787, 35315273, 38848718,
#         35421113, 33315656, 38086634, 30114157, 33206147, 38320237,
#         35420907, 37351332, 39699150, 31346589, 31151696, 36591813,
#         30942855, 36596503, 30946765, 34278605, 39984868, 39224356,
#         37238447, 35008915, 39197730, 30238398, 37961886
#     ],
#     '_id': [
#         '66ac856a070f0b6e27cee826', '66ac85e5070f0b6e27cee829', '66ac873b070f0b6e27cee82f',
#         '66ac8702070f0b6e27cee82e', '66ac88cc070f0b6e27cee836', '66ac844a070f0b6e27cee821',
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   json_i    990 non-null    int64
#  1   _id       990 non-null    object
#  2   question  990 non-null    object
#  3   answer    990 non-null    object
#  4   data      990 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 38.8+ KB

# %%
def format_data(question, json_data_used, question_data_mapping):
    data_info = question_data_mapping.get(question)
    if not data_info:
        return None

    if isinstance(data_info["collection"], list):
        values = []
        for field_pair in data_info["fields"]:
            if isinstance(field_pair, tuple):
                triage_values = [json_data_used.get("ED-Triage-prammed", {}).get(field, "nan") for field in field_pair]
                vitals_values = [json_data_used.get("ED-VitalSigns-prammed", {}).get(field, "nan") for field in field_pair]
                values.extend(triage_values + vitals_values)
            else:
                triage_value = json_data_used.get("ED-Triage-prammed", {}).get(field_pair, "nan")
                vitals_value = json_data_used.get("ED-VitalSigns-prammed", {}).get(field_pair, "nan")
                values.extend([triage_value, vitals_value])
        return data_info["format"].format(*values)
    else:
        collection_data = json_data_used.get(data_info["collection"], {})
        if collection_data is None:
            collection_data = {}
        return collection_data.get(data_info["field"], "nan")

def fill_data_column(df, input_json, question_data_mapping):
    for index, row in df.iterrows():
        question = row['question']
        json_i = row['json_i']
        record = input_json[json_i]
        
        data = format_data(question, record['json_data_used'], question_data_mapping)
        df.at[index, 'data'] = data if data is not None else 'nan'
    
    return df

# %%
df_filled = fill_data_column(df_basic, input_json, question_data_mapping)
df_filled.insert(df_filled.columns.get_loc('data') + 1, 'Class', '')

# %%
df_filled.head(2)
# Out:
#    json_i                       _id             question  \
# 0       0  669933e4afbfd9c3c2d8efd0       chiefcomplaint
# 1       0  669933e4afbfd9c3c2d8efd0  medication_reported
#
#                                                                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0                                                  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
# 1  1. Acetaminophen 325mg TAB\n2. OxyContin (Oxycodone)\n3. Two 10mg tablets of an unknown medication (assumed to be a pain medication, possibly a generic or brand name of Oxycodone) taken in the morning.\n-------\nPlease extract every single pharmaceuticals, drugs and medications that the patient says he has taken or is taking as a list, like: Aspirin 1 tablet; Paracetamol; Antihistamine!
#
#                                      data Class
# 0  Lower back pain, L Knee pain, Headache
# 1                   oxycodone [OxyContin]

# %% [markdown]
# # Postprocessing with openai
# Was:      Inthalte von data und answer post-processen, so das wir Similarity Scores berechnen können.
# Warum:    Data sind prammed-MIMIC-iv Daten direkt übernommen, haben aber Abkürzungen, unterdiagnossen etc.
#           Das macht Probleme mit similarity scores.
# Wie:      OpenAI-API nutzen um aus data, answer direkt eine csv zu erstellen.

# %% [markdown]
# ## PSEUDOCODE
#
#
# gpt_model = chosen model
#
# ### Load environment variables from a specified .env file for secure API key storage
# #env_path = '/Users/mosimacnew/Code/AIdoCS/openAPI/openAI_Token.env'
# env_path = '/home/msd4/aidocsMosi/openAI_Token.env'
# load_dotenv(dotenv_path=env_path)
#
# ### Retrieve the OpenAI API key from the environment variables
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# if not OPENAI_API_KEY:
#     # Raise an error if the API key is not found, to prevent API calls without authentication
#     raise ValueError("No API key found. Please set your OPENAI_API_KEY in the .env file.")
#
# ### Initialize the OpenAI client with the retrieved API key
# client = openai.OpenAI(api_key=OPENAI_API_KEY)
#
#
#
# promptemplate_conditions =
#     """
#     Please do this and that from this text:
#     '''
#     {text}
#     '''and return a csv.
#     """
#
# promptemplate_drugs =
#     """
#     Please do this and that from this text:
#     '''
#     {text}
#     '''and return a csv.
#     """
#
# promptemplate_measures =
# """
#
# """
#
#
#
# def gptMakeCsvArray(text, template, gpt_model): array
#
#     openai_object = callOpenai(text,template)
#     answer = openai_object.getResponse
#     print(answer)
#     answer_array_for_df = answer
#
#     return answer_array_for_df
#
#
# def loopGptMakeCsv (df:df, dfColumnName:string, template:promttemplate, range(0=start:int, end=11;int, all:string) : df
#
#     df_infput = df.copy()
#     cellOfColumnToProcess = dfColumnName (either 'data' or 'answer' eg.)
#     newColumnName = dfColumnName+'gpt-csv'
#     promptTemplateToUse = template
#
#     range // either 0,x, or all
#     start_range = start
#     end_range =    end
#         if all then length of df_input = 0,max
#
#     df_to_loop_through = df_input[0:max]
#
#     for each row in range in df_to_loup_through
#         text = df_to_loup_through[row, dfColumnName].tostring()
#         csv_array = gptMakeCsvArray(text, promptTemplateToUse)
#         df_to_loop_through addNewcolum newColumnName at row
#         df_to_loop_through[dfColumnName+'delimiter'] insert csv_array
#
#     return df_to_loop_through

# %%
df_unprocessed = df_filled.copy()
df_unprocessed.head(5)
# Out:
#    json_i                       _id             question  \
# 0       0  669933e4afbfd9c3c2d8efd0       chiefcomplaint
# 1       0  669933e4afbfd9c3c2d8efd0  medication_reported
# 2       0  669933e4afbfd9c3c2d8efd0     medication_pyxis
# 3       0  669933e4afbfd9c3c2d8efd0            diagnosis
# 4       0  669933e4afbfd9c3c2d8efd0                   bp
#
#                                                                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0                                                  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
# 1  1. Acetaminophen 325mg TAB\n2. OxyContin (Oxycodone)\n3. Two 10mg tablets of an unknown medication (assumed to be a pain medication, possibly a generic or brand name of Oxycodone) taken in the morning.\n-------\nPlease extract every single pharmaceuticals, drugs and medications that the patient says he has taken or is taking as a list, like: Aspirin 1 tablet; Paracetamol; Antihistamine!
# 2                                              Acetaminophen, OxyContin\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single pharmaceuticals, drugs, medications that the patient is taking or has taken prior to the ambulance crew's intervention as a csv-list of only names/labels, like: Aspirin x mg; Paracetamol; antihistamine!
# 3                                                                                                                                                              1. Radiculopathy in the lumbar region\n2. Lower back pain\n3. Knee pain\n4. Headache\n5. Severe pain (back, 7 out of 10)\n6. Pain in the lumbar region\n7. Possible underlying medical condition for the symptoms (not specified)  END OF
# 4                                                                                                                                                                                                                                                                                                                                                                             165 over 103; 165 over 105
#
#                                      data Class
# 0  Lower back pain, L Knee pain, Headache
# 1                   oxycodone [OxyContin]
# 2                 Acetaminophen 325mg TAB
# 3            Radiculopathy, lumbar region
# 4        triage: 165 105; vitals: 165 103

# %%
# Für Openai aidocs kernel brauchen

# %%
import os
import openai
import pandas as pd
from dotenv import load_dotenv

# %%
# Load environment variables from a specified .env file for secure API key storage
env_path = '/home/msd4/aidocsMosi/openAI_Token.env'
load_dotenv(dotenv_path=env_path)

# Retrieve the OpenAI API key from the environment variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    raise ValueError("No API key found. Please set your OPENAI_API_KEY in the .env file.")

# Initialize the OpenAI client with the retrieved API key
openai.api_key = OPENAI_API_KEY

# %%
# Final
prompt_template_conditions_data = """
Please extract the relevant medical conditions from the following text and return a comma-separated list. Follow these rules:
- Convert all items to lower case.
- Write out abbreviations.
- Remove duplicates, keeping only one instance.
- If the text contains a specific subgroup (e.g., "Coffee Ground Emesis"), keep the original and also add the general terminology.
- Expand terms with multiple components into all relevant variations without losing medical context. For example:
  - "s/p Fall, L Hand injury, Head injury" should become "s/p fall, status post fall, l hand injury, left hand injury, hand injury, head injury".
  - "TETANUS TOXOID INOCULAT" should become "tetanus toxoid inoculation, tetanus inoculation, tetanus".
  - "Anemia, unspecified" should become "anemia unspecified, anemia".
  - "L Knee swelling, Abnormal labs" should become "l knee swelling, left knee swelling, knee swelling, abnormal labs, abnormal lab results".
  - "Long term (current) use of aspirin" should become "long term (current) use of aspirin, long term use of aspirin, use of aspirin, aspirin use, aspirin".
  - "Lower back pain, MVC, Neck pain" should become "lower back pain, motor vehicle accident, mvc, neck pain".
  - "Post-traumatic stress disorder, unspecified" should become "post-traumatic stress disorder, post traumatic stress disorder, traumatic stress disorder".

Here is the text:
'''
{text}
'''
"""

# %% [raw]
# prompt_template_conditions_answer = """
# Please extract the relevant medical conditions, diagnosis and issues from the following text and return a comma-separated list. Follow these rules:
# - Convert all items to lower case.
# - Write out abbreviations where necessary.
# - Remove single numbers and special characters.
# - Do not use line breaks; keep everything in one line.
# - Condense longer descriptions into single words or short phrases while retaining medical meaning.
# - Correct any obvious spelling mistakes (e.g., "hest pain" to "chest pain").
# - Keep general terms to ensure medical context but reduce unnecessary variations. For example:
#   - "No previous health problems mentioned.\n- No persisting health problems mentioned.\n- Symptoms reported: severe pain (rated 7 on a scale of 0 to 10), started a few hours ago, getting worse." should become "no previous health problems, severe pain".
#   - "Chest pain\n- Low blood pressure\n- Tachypnea (respiratory rate of 19 breaths per minute, which is higher than normal)\n- Bradycardia (heart rate of 67 beats per minute, which is lower than normal)\n- Possible hypotension (blood pressure of 121 over 80)" should become "chest pain, low blood pressure, tachypnea, bradycardia, possible hypotension".
#   - "Unsteadiness on feet" should become "unsteadiness on feet, unsteadiness".
# - Also list the wounds and injuries.
# - List the content in parentheses also separately.
#
# Here is the text:
# '''
# {text}
# '''
# """

# %%
# Added "Do not list diagnoses or conditions that that are ruled out", because rag-llm tended to fill out max length with "ruled out"-conditions in some cases (2 seen)

prompt_template_conditions_answer = """
Please extract the relevant medical conditions, diagnosis and issues from the following text and return a comma-separated list. Follow these rules:
- Convert all items to lower case.
- Write out abbreviations where necessary.
- Remove single numbers and special characters.
- Do not use line breaks; keep everything in one line.
- Condense longer descriptions into single words or short phrases while retaining medical meaning.
- Correct any obvious spelling mistakes (e.g., "hest pain" to "chest pain").
- Keep general terms to ensure medical context but reduce unnecessary variations. For example:
  - "No previous health problems mentioned.\n- No persisting health problems mentioned.\n- Symptoms reported: severe pain (rated 7 on a scale of 0 to 10), started a few hours ago, getting worse." should become "no previous health problems, severe pain".
  - "Chest pain\n- Low blood pressure\n- Tachypnea (respiratory rate of 19 breaths per minute, which is higher than normal)\n- Bradycardia (heart rate of 67 beats per minute, which is lower than normal)\n- Possible hypotension (blood pressure of 121 over 80)" should become "chest pain, low blood pressure, tachypnea, bradycardia, possible hypotension".
  - "Unsteadiness on feet" should become "unsteadiness on feet, unsteadiness".
- Also list the wounds and injuries.
- List the content in parentheses also separately.
- Do not list diagnoses or conditions that that are ruled out.
Here is the text:
'''
{text}
'''
"""

# %%
prompt_template_drugs_data = """
Please extract the relevant drugs mentioned in the following text and return a comma-separated list in CSV format. Follow these rules:
- Clean all special characters, including dots.
- Convert all terms to lowercase.
- Ensure forms and dosages are not mentioned alone without the drug name or active ingredient.
- Keep the translated original term and append variations. Variations should include:
  - One original term with dosage.
  - One without dosage.
  - Only market label name if present in data but keep original label names.
  - Include the active ingredient name if present.
- For example:
  - "Lantus Solostar U-100 Insulin" should become "lantus solostar u-100 insulin, lantus solostar insulin, lantus solostar, lantus insulin, insulin".
  - "Morphin 2 tabletten" should become "morphine 2 tabs, morphine tabs, morphine".
  - "DiphenhydrAMINE 25mg CAP" should become "diphenhydramine 25mg cap, diphenhydramine 25mg capsules, diphenhydramine capsules, diphenhydramine 25mg, diphenhydramine".
  - "Oxycodone [OxyContin]" should become "oxycodone oxycontin, oxycodone, oxycontin".
  - "Vitamin D2" should become "vitamin d2, vit d2".
  - "MetRONIDAZOLE (Flagyl)" should become "metronidazole flagyl, metronidazole, flagyl".
  - "Tetanus-DiphTox-Acellular Pertuss" should become "tetanus-diphtox-acellular pertuss, tetanus diphtox acellular pertuss, tetanus diphteria pertussis vaccine, tetanus diphteria pertussis, tetanus vaccine, diphteria vaccine, pertussis vaccine".
  - "Ampicillin-Su 3g/100mL 100mL BAG" should become "ampicillin-su 3g/100ml 100ml bag, ampicillin-su 3g/100ml 100ml, ampicillin-su bag, ampicillin-su, ampicillin".
- Remove hyphens after keeping the original term.
- Remove duplicates from the final CSV list.
- Ensure the final list is comma-separated.

Here is the text:
'''
{text}
'''
"""

# %%
# Final
prompt_template_drugs_answer = """
Please extract the relevant drugs mentioned in the following text and return a comma-separated list in CSV format. Follow these rules:
- Clean all special characters, including dots.
- Convert all terms to lowercase.
- Ensure forms and dosages are not mentioned alone without the drug name or active ingredient.
- If an item has only dosage or form information (e.g., "2 tabs in the morning"), mark it as "2 tabs with no further information".
- Keep the translated original term and append variations within the same item. Variations should include:
  - One original term with dosage.
  - One without dosage.
  - Only market label name if present in data but keep original label names.
  - Include the active ingredient name if present.
- Variations should only be done within the same text-list-item and not combined with other items.
- Remove hyphens after keeping the original term.
- Remove duplicates from the final CSV list.
- Remove non-drug related information.
- If the text contains valid drug names without additional information, include them as they are.
- If no drug-related information is available, insert only: "no information at all".
- Ensure the final list is comma-separated.

Here is the text:
'''
{text}
'''
"""

# %%
def call_openai(text, template):
    prompt = template.format(text=text)
    response = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ],
        temperature=0.7,
        max_tokens=150
    )
    return response.choices[0].message.content

def gpt_make_csv_array(text, template):
    response_text = call_openai(text, template)
    csv_array = [item.strip() for item in response_text.split(',')]
    print(response_text)
    return csv_array

def loop_gpt_make_csv(df, df_column_name, template, questions_to_process, start=0, end=None):
    df_input = df.copy()
    cell_of_column_to_process = df_column_name
    new_column_name = df_column_name + '_gpt_csv'

    if end is None:
        end = len(df_input)
        
    # Filter the dataframe based on the specified questions
    df_to_loop_through = df_input[df_input['question'].isin(questions_to_process)].iloc[start:end]

    # Initialize the new column with empty lists
    df_input[new_column_name] = [[] for _ in range(len(df_input))]

    for idx, row in df_to_loop_through.iterrows():
        text = str(row[cell_of_column_to_process])
        csv_array = gpt_make_csv_array(text, template)
        df_input.at[idx, new_column_name] = csv_array  # Assign the array directly

    return df_input


def loop_gpt_make_csv(df, df_column_name, template, questions_to_process, start=0, end=None):
    df_input = df.copy()
    cell_of_column_to_process = df_column_name
    new_column_name = 'data_gpt' if df_column_name == 'data' else 'answer_gpt'

    if new_column_name not in df_input.columns:
        # Initialize the new column with empty lists if it doesn't exist
        df_input[new_column_name] = [[] for _ in range(len(df_input))]

    if end is None:
        end = len(df_input)
        
    # Filter the dataframe based on the specified questions
    df_to_loop_through = df_input[df_input['question'].isin(questions_to_process)].iloc[start:end]

    for idx, row in df_to_loop_through.iterrows():
        if not row[new_column_name]:  # Only fill if the cell is empty
            text = str(row[cell_of_column_to_process])
            csv_array = gpt_make_csv_array(text, template)
            df_input.at[idx, new_column_name] = csv_array  # Assign the array directly

    return df_input

# %% [markdown]
# ### Postprocess conditions

# %%
# Postprocess data
processed_df = df_unprocessed
questions_to_process = ['chiefcomplaint', 'diagnosis']
processed_df = loop_gpt_make_csv(processed_df, 'data', prompt_template_conditions_data, questions_to_process, start=0, end=None)
# Out:
# lower back pain, l knee pain, headache, knee pain, head pain
# radiculopathy, lumbar region, lumbar radiculopathy, radiculopathy
# chest pain, nstemi, non-st elevation myocardial infarction, myocardial infarction
# unspecified speech disturbances, speech disturbances
# hematuria, r flank pain, hematuria, flank pain, right flank pain
# pregnancy related conditions, third trimester
# n/v/d, nausea, vomiting, diarrhea
# intracranial hemorrhage unspecified, intracranial hemorrhage, hemorrhage
# multiple falls
# chest pain, chest pain not elsewhere classified, chest pain nec
# alcohol abuse, alcohol use disorder, etoh, vomiting
# diabetes mellitus, diabetes
# tooth abscess, abscess
# cellulitis of face, cellulitis
# l arm laceration, left arm laceration, arm laceration, self-injury, si
# disruption of external operation wound, surgical wound, wound
# rlq abdominal pain, right lower quadrant abdominal pain, abdominal pain
# anemia unspecified, anemia
# altered mental status, mental status
# bradycardia, unspecified, bradycardia
# leg infection, leg inflammation, leg cellulitis, cellulitis
# epilepsy, recurrent seizures, without mention of intractable epilepsy, other forms of epilepsy
# body aches, dyspnea, shortness of breath
# heart failure, congestive heart failure
# depression
# headache
# No relevant medical conditions were extracted from the provided text. If you provide more detailed information or context, I would be happy to assist further.
# aortocoronary bypass, bypass
# llq abdominal pain, n/v, nausea vomiting, abdominal pain
# abdominal pain epigastric, epigastric pain
# headache, visual changes
# sepsis, unspecified organism, sepsis
# nausea, vomiting
# nausea
# ear pain
# transient cerebral ischemia, transient ischemic attack, cerebral ischemia, ischemia, nos
# vaginal bleeding, vag bleed
# antibiotic adverse effects, antoinfection effects, antoinfection.
# brbpr, bright red blood per rectum, blood in stool
# nontraumatic intracranial hemorrhage, intracranial hemorrhage, hemorrhage
# chest pain, neck pain
# diabetes mellitus type 2, type 2 diabetes, diabetic neuropathy, neuropathy
# coffee ground emesis, coffee ground vomiting, emesis, vomiting
# abdominal pain periumbilic, abdominal pain
# back pain, chest pain
# hypothyroidism, hypothyroidism not otherwise specified, nos
# asthma exacerbation, asthma
# hallucinations
# l foot injury, left foot injury, foot injury, pregnancy
# cellulitis of face, cellulitis
# bike accident, bicycle accident, accident
# distal phalanx fracture of right index finger, open fracture, open fx, finger fracture, index finger fracture
# fall, status post fall, r shoulder injury, right shoulder injury, shoulder injury, lower back pain, back pain
# sciatica

# %% [raw]
# filtered_df = processed_df.loc[processed_df['question'].isin(['chiefcomplaint', 'diagnosis'])].copy()
# filtered_df.head(1)

# %%
# Save to CSV or handle the DataFrame as needed
processed_df.to_csv('processed_output-conditions-data-gpt.csv', index=False)

# %%
# Now lets progress with postprossessing
#df_in = processed_df
questions_to_process = ['chiefcomplaint', 'diagnosis']
processed_df = loop_gpt_make_csv(processed_df, 'answer', prompt_template_conditions_answer, questions_to_process, start=0, end=None)
# Out:
# lower back pain, knee pain, headache, trouble sleeping, affecting mood and energy levels
# radiculopathy, lower back pain, knee pain, headache, severe pain, lumbar region, possible underlying medical condition
# high cholesterol, dizziness, lightheadedness, shortness of breath, feeling out of breath, allergic to penicillin
# ambulance, asymptomatic hiv infection, high cholesterol, respiratory distress, shortness of breath, dizziness, elevated heart rate, high respiratory rate, wounds: chest pain, pressure, hiv infection.
# cardiac issue, beta blockers, cardiac selective, vaginal bleed, chest pain, shortness of breath, dizziness, weakness, possible pulmonary embolism, adv eff antinfct nec nos, possible myocardial infarction, heart attack, possible cardiac arrest, possible hemorrhage.
# high blood pressure, diabetes, headache, sweating a lot, numbness in the right side of the face, weakness in the right side of the body, difficulty speaking, difficulty moving the right side of the body, difficulty swallowing, difficulty seeing, dizziness, confusion, unusual feeling, previous intracranial hemorrhage.
# high blood pressure, diabetes, intracranial hemorrhage, abnormal heart rate, sweating, pain, low oxygen saturation, possible cardiac event
# chest pain, neck pain, stiff, pain in legs and feet, dizziness, lightheadedness, type 2 diabetes, diabetic neuropathy
# type 2 diabetes mellitus, diabetic neuropathy, chest pain, neck pain, dizziness, lightheadedness, pain in legs and feet, stiff neck, back of neck pain, possible cardiac issues, cardiac arrest.
# fatigue, vomiting, severe pain, coffee grounds in the vomit, lovastatin
# peritonitis, appendicitis, diverticulitis, intussusception, ovarian torsion, ectopic pregnancy, ruptured ectopic pregnancy, hemorrhagic ovarian cyst, ruptured ovarian cyst, ovarian hemorrhage, hemorrhagic ovarian torsion, intestinal obstruction, intestinal perforation, inflammatory bowel disease, gastrointestinal perforation, gastrointestinal bleeding, gastrointestinal obstruction, gastrointestinal infarction, gastrointestinal ischemia, gastrointestinal necrosis.
# fatigue, weight gain, muscle weakness, back pain, chest pain, nausea, allergy to penicillin, suspected hypothyroidism NOS, rosuvastatin, birth control pills
# hypothyroidism, chest pain, back pain, fatigue, nausea, shortness of breath, dizziness, cholesterol, thyroid gland issue, possible cardiac issue
# asthma, congestion, cough, shortness of breath, heart condition (isosorbide mononitrate), possible allergy (pollen), isosorbide mononitrate.
# asthma attack, respiratory distress, possible pneumonia, possible bronchitis, exacerbation of chronic lung disease, hypoxemia, tachypnea, tachycardia, hypotension, possible respiratory failure, wounds and injuries: none
# infection, pain in left foot, fall, hurt left foot, numbness or tingling, no other symptoms, no prior health problems, no prior symptoms
# fall-related injury, pain, infection, inflammation, possible fracture, possible internal injury, possible soft tissue injury, hypertension, tachycardia, tachypnea, fever, possible internal bleeding, hematoma
# allergies to penicillin and other substances, leg pain, possible dizziness, possible confusion
# displaced fracture right index finger, possible fracture leg, pain leg, allergies penicillin, dizziness, confusion, hematoma possible consequence fall, cardiac arrest, respiratory distress, cardiac condition.
# sciatica, heart attack, lower back pain, right leg numbness, shoulder pain, back pain
# sciatica, shoulder pain, back pain, possible injury, falling down stairs, shoulder injury, back injury, pain rated 7, pain rated 5 or 6, pain rated 4 or 5

# %%
processed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   json_i      990 non-null    int64
#  1   _id         990 non-null    object
#  2   question    990 non-null    object
#  3   answer      990 non-null    object
#  4   data        990 non-null    object
#  5   Class       990 non-null    object
#  6   data_gpt    990 non-null    object
#  7   answer_gpt  990 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 62.0+ KB

# %% [raw]
# filtered_df = processed_df.loc[processed_df['question'].isin(['chiefcomplaint', 'diagnosis'])].copy()
# filtered_df.head(1)

# %% [markdown]
# ### postprocess medication

# %% [raw]
# # Filter the DataFrame
# inspect_df_medi = processed_df[processed_df['question'].isin(['medication_reported', 'medication_pyxis'])].copy()
# inspect_df_medi.head(5)

# %%
questions_to_process = ['medication_reported', 'medication_pyxis']
processed_df = loop_gpt_make_csv(processed_df, 'data', prompt_template_drugs_data, questions_to_process, start=0, end=None)
# Out:
# oxycodone oxycontin, oxycodone, oxycontin
# acetaminophen 325mg tab, acetaminophen 325mg tablets, acetaminophen tablets, acetaminophen.
# simvastatin, simvastatin, statin
# omeprazole, omeprazole, prilosec, prilosec, prilosec otc
# ergocalciferol vitamin d2, ergocalciferol, vitamin d2
# ibuprofen 400mg tab, ibuprofen 400mg, ibuprofen tab, ibuprofen
# suboxone, suboxone, suboxone, suboxone
# bisacodyl, bisacodyl
# pravachol, pravachol, pravastatin
# acetaminophen with codeine 1tab, acetaminophen with codeine tabs, acetaminophen with codeine, acetaminophen codeine, acetaminophen, codeine
# norvir, norvir
# diphenhydramine 25mg cap, diphenhydramine 25mg capsules, diphenhydramine capsules, diphenhydramine 25mg, diphenhydramine
# desmopressin, desmopressin, desmopressin
# oxydone immediate release, oxydone immediate release, oxydone, immediate release, oxydone
# trileptal, trileptal, oxcarbazepine
# spironolactone, spironolactone, aldactone
# ramipril, ramipril
# levetiracetam, levetiracetam, levetiracetam, levetiracetam
# metoprolol tartrate lopressor, metoprolol tartrate, lopressor, metoprolol.
# acetaminophen codeine 1tab tab, acetaminophen codeine 1tab, acetaminophen codeine, acetaminophen, codeine
# zemplar, zemplar, paricalcitol
# sulfameth/trimeth ds 1tab tab, sulfameth/trimeth ds 1tab, sulfameth/trimeth ds, sulfameth trimeth, sulfameth, trimeth.
# metoprolol tartrate lopressor, metoprolol tartrate, lopressor, metoprolol
# atorvastatin, atorvastatin, atorvastatin
# simvastatin, simvastatin, simvastatin
# simvastatin, simvastatin, simvastatin
# metoprolol tartrate lopressor, metoprolol tartrate, lopressor, metoprolol
# losartan potassium, losartan potassium, losartan, potassium.
# atorvastatin
# vancomycin
# bayer aspirin, bayer, aspirin
# pregabalin, pregabalin
# pravastatin pravachol, pravastatin, pravachol
# warfarin 5mg tab, warfarin 5mg tabs, warfarin tabs, warfarin 5mg, warfarin
# aspirin adult low dose aspirin, aspirin adult low dose, aspirin, adult low dose, adult low dose aspirin
# fentanyl patch 100mcg/h ptc, fentanyl patch 100mcg/h, fentanyl patch, fentanyl
# simvastatin, simvastatin, statin
# calcium gluconate, calcium gluconate, calcium gluconate, calcium, gluconate
# simvastatin, simvastatin
# simvastatin, simvastatin, simvastatin
# isosorbide mononitrate imdur, isosorbide mononitrate, imdur.
# lamotrigine, lamotrigine, lamotrigine, lamotrigine
# pravachol, pravachol, pravastatin
# paroxetine, paroxetine, paroxetine, paroxetine
# toprol xl, toprol, xl
# magnesium sulfate, magnesium sulfate, magnesium, sulfate
# isosorbide mononitrate imdur, isosorbide mononitrate, imdur.
# ampicillin-sulbactam, ampicillin sulbactam, ampicillin sulbactam, ampicillin, sulbactam
# simvastatin, simvastatin
# amitriptyline 25mg tab, amitriptyline 25mg tabs, amitriptyline tabs, amitriptyline 25mg, amitriptyline
# lansoprazole prevacid, lansoprazole, prevacid
# acetaminophen wcodeine 1tab tab, acetaminophen wcodeine 1tab, acetaminophen codeine, acetaminophen, codeine
# aspirin aspirin childrens, aspirin, aspirin childrens
# nitroglycerin 100mg/250ml 250ml btl, nitroglycerin 100mg/250ml, nitroglycerin 250ml btl, nitroglycerin 100mg, nitroglycerin
# hydromorphone, hydromorphone, hydromorphone
# acetaminophen codeine 1tab, acetaminophen codeine tabs, acetaminophen codeine, acetaminophen, codeine
# combivir, combivir, combivir
# norepinephrine 8mg/250ml 250ml bag, norepinephrine 8mg/250ml, norepinephrine bag, norepinephrine
# rivastigmine tartrate, rivastigmine, tartrate
# hydrocodone-acetaminophen, hydrocodone acetaminophen, hydrocodone, acetaminophen
# lamictal, lamictal
# mirtazapine, mirtazapine, mirtazapine
# lansoprazole prevacid,lansoprazole,prevacid
# fentanyl, fentanyl
# rosuvastatin crestor, rosuvastatin, crestor
# hydromorphone 2mg tab, hydromorphone 2mg tablet, hydromorphone tab, hydromorphone tablet, hydromorphone, dilaudid
# simvastatin, simvastatin
# midazolam, midazolam
# buspirone, buspirone
# ampicillin-su 3g/100ml 100ml bag, ampicillin-su 3g/100ml 100ml, ampicillin-su bag, ampicillin-su, ampicillin
# omeprazole prilosec, omeprazole, prilosec
# levothyroxine sodium 25mcg tab, levothyroxine sodium 25mcg tabs, levothyroxine sodium tab, levothyroxine sodium, levothyroxine
# simvastatin, simvastatin
# atorvastatin 40mg tab, atorvastatin 40mg, atorvastatin tab, atorvastatin
# rosuvastatin crestor, rosuvastatin, crestor
# magnesium sulf 2gm/50ml 50ml bag, magnesium sulf 2gm/50ml, magnesium sulf bag, magnesium sulf
# metoprolol tartrate lopressor, metoprolol tartrate, lopressor, metoprolol.
# vancomycin
# bisoprolol fumarate, bisoprolol, fumarate
# lamotrigine, lamotrigine, lamotrigine, lamotrigine
# finasteride, finasteride
# lamotrigine, lamotrigine, lamotrigine.
# metoprolol tartrate, metoprolol, tartrate
# lactulose, lactulose
# pravastatin, pravastatin, pravastatin
# aspirin ec, aspirin
# bisoprolol fumarate, bisoprolol, fumarate
# acetaminophen 500mg tab, acetaminophen 500mg, acetaminophen tab, acetaminophen.
# rivastigmine tartrate, rivastigmine, tartrate
# pantoprazole sodium, pantoprazole, sodium
# bayer aspirin, bayer aspirin, aspirin
# acetaminophen 500mg tab, acetaminophen 500mg tabs, acetaminophen tabs, acetaminophen 500mg, acetaminophen
# lovastatin, lovastatin
# tetanus-diphtox-acellular pertuss, tetanus diphtox acellular pertuss, tetanus diphteria pertussis vaccine, tetanus diphteria pertussis, tetanus vaccine, diphteria vaccine, pertussis vaccine
# rosuvastatin, rosuvastatin, statin
# atorvastatin 40mg tab, atorvastatin 40mg tablet, atorvastatin tab, atorvastatin
# isosorbide mononitrate, isosorbide mononitrate, isosorbide mononitrate, isosorbide, mononitrate
# metronidazole flagyl, metronidazole, flagyl
# milk of magnesia, milk of magnesia, magnesia, milk, magnesia
# clindamycin, clindamycin
# suboxone, suboxone, suboxone, suboxone
# methadone dispersible tablet, methadone dispersible, methadone tablet, methadone
# toprol xl, toprol, xl
# oxycodone-acetaminophen 1tab, oxycodone-acetaminophen tabs, oxycodone-acetaminophen, oxycodone acetaminophen, oxycodone, acetaminophen

# %% [raw]
# filtered_df = processed_df_medication_data.loc[processed_df_medication_data['question'].isin(['medication_reported', 'medication_pyxis'])].copy()
# filtered_df.head(1)

# %%
questions_to_process = ['medication_reported', 'medication_pyxis']
processed_df = loop_gpt_make_csv(processed_df, 'answer', prompt_template_drugs_answer, questions_to_process, start=0, end=None)
# Out:
# acetaminophen, oxycodone, unknown medication, no information at all
# acetaminophen, paracetamol; oxycontin
# omeprazole,omeprazole,omeprazole,simvastatin,aspirin,aspirin 1 tablet,paracetamol,antihistamine,no information at all
# omeprazole, simvastatin
# ibuprofen,ibuprofen 400mg,ibuprofen,400mg,ibuprofen tab,ergocalciferol,vitamins d derivatives
# ibuprofen,ibuprofen 200mg,paracetamol,aspirin,antihistamine,no information at all
# bisacodyl, bisacodyl 5mg, blood pressure medication, blood pressure medication with no further information, penicillin, penicillin allergy, suboxone
# bisacodyl,suboxone,phenyltriazine derivatives,anticonvulsant
# acetaminophen, codeine, pravachol
# acetaminophen with codeine, pravachol
# ibuprofen, ibuprofen 200mg, norvir, diphenhydramine, diphenhydramine 25mg, diphenhydramine 2 tabs with no further information
# diphenhydramine, diphenhydramine 25mg, ibuprofen, ibuprofen 200mg, norvir, no information at all
# desmopressin,penicillin,no information at all
# oxycodone, desmopressin
# trileptal, trileptal 200mg, calcium channel blockers, calcium channel blockers 200mg, dihydropyridines, spironolactone
# trileptal, trileptal, oxcarbazepine
# spironolactone, spironolactone, spironolactone
# ramipril,ramipril,levetiracetam,levetiracetam
# levetiracetam,ramipril
# metoprolol tartrate, acetaminophen, codeine, no information at all
# metoprolol tartrate, metoprolol tartrate 50mg, Acetaminophen w/Codeine, Acetaminophen with Codeine, Acetaminophen, Codeine
# zemplar,purine analogs,sulfameth/trimeth ds,1tab with no further information
# sulfameth/trimeth ds, trimethoprim/sulfamethoxazole, zemplar, paricalcitol, no information at all
# lopressor, atorvastatin, beta blocker, atorvastatin, hypertension, blood pressure, no information at all
# atorvastatin, lopressor
# simvastatin, simvastatin 1 tablet, simvastatin for cholesterol
# simvastatin,simvastatin 40mg,simvastatin 40,pain medication,no information at all,oxygen
# metoprolol tartrate, metoprolol, losartan potassium, losartan, no information at all
# metoprolol tartrate, metoprolol, losartan potassium, losartan
# atorvastatin, vancomycin
# atorvastatin,atorvastatin calcium,Vancomycin, no information at all
# bayer aspirin, aspirin; salicylate analgesics
# pregabalin, pregabalin; 2 tabs with no further information
# no information at all
# aspirin, pregabalin
# pravastatin, pravastatin (morning), warfarin, warfarin (administered by the ambulance crew)
# pravastatin, warfarin
# aspirin, low dose aspirin, salicylate analgesics, no information at all
# aspirin, fentanyl patch, salicylate analgesics, no information at all
# simvastatin, simvastatin, calcium gluconate
# simvastatin, simvastatin, calcium gluconate, no information at all
# simvastatin, simvastatin 2 tabs with no further information
# simvastatin, no information at all
# isosorbide mononitrate, imdur, beta blockers, lamotrigine, penicillin, chronic bronchitis medication, no information at all
# beta blockers, imdur, lamotrigine, penicillin, no information at all
# pravachol, pravachol, for cholesterol
# paroxetine, paroxetine, prescribed by doctor
# no information at all
# pravachol, paroxetine, aspirin, paracetamol, antihistamine, no information at all
# toprol xl, metoprolol, magnesium sulfate, magnesium, arbs, angiotensin receptor blockers no information at all
# toprol xl, metoprolol, magnesium sulfate, magnesium, arbs, angiotensin receptor blockers, no information at all
# imdur,imdur,imdur,beta blockers cardiac selective,ampicillin-sulbactam,ampicillin-sulbactam,ems crew, no information at all
# imdur, imdur 30mg, ampicillin-sulbactam, ampicillin sulbactam, no information at all
# aspirin, low dose aspirin, hydrocodone, dilaudid, penicillin, xanthine oxidase inhibitors, hyperuricemia therapy, hydrocodone 2mg tab, hydrocodone 2mg, penicillin no information at all
# aspirin, hydrocodone, dilaudid, no information at all
# cefeprime, simvastatin
# cefePIME, cefepime, simvastatin, no information at all
# ibuprofen,rosuvastatin,atorvastatin,penicillin,penicillin (allergic to),blood pressure medication,no information at all
# ibuprofen,rosuvastatin,atorvastatin,antibiotics through an iv,antibiotics through an iv with no further information,no information at all
# paxil, dihydropyridines, no information at all
# paxil,fluorescein strip
# pravastatin, pravastatin, pravachol,
# dexamethasone, dexamethasone, dexamethasone 1 milliliter intravenously, dexamethasone 1 milliliter intravenously,
# no information at all
# pravastatin,pravastatin  with no further information,pravachol,dexamethasone
# cough syrup,metoprolol succinate,metoprolol,bisacodyl
# bisacodyl, metoprolol succinate
# imdur, imdur 1 tablet, isosorbide mononitrate, lopressor, lopressor 1 tablet, metoprolol, zocor, zocor 1 tablet, simvastatin, hydrocortison, hydrocortison 1 tablet, hydrocortisone, aspirin 2 tabs with no further information, paracetamol 1 tablet, antihistamine, no information at all
# lopressor, zocor, imdur, hydrocortison, metoprolol
# buspirone,calcium channel blockers,dihydropyridines,sodium bicarbonate, no information at all
# buspirone, sodium bicarbonate, no information at all
# omeprazole, omeprazole, cephalexin, cephalexin, no information at all
# cephalexin, omeprazole
# albuterol, albuterol sulfate, albuterol for asthma, albuterol for copd, albuterol inhaled, albuterol short acting, albuterol sulfate for asthma, albuterol sulfate for copd, albuterol sulfate inhaled, albuterol sulfate short acting, acetaminophen, acetaminophen 325mg tablets, acetaminophen for pain, penicillin, allergic to penicillin
# acetaminophen, albuterol
# metoprolol tartrate,metoprolol,amoxicillin-clavulanic acid,amoxicillin,clavulanic acid
# metoprolol tartrate, amoxicillin-clavulanic acid
# ibuprofen,advil,levetiracetam
# levetiracetam,levetiracetam,ibuprofen,ibuprofen,advil
# amlodipine, gentamicin, premix with no information
# gentamicin, amlodipine, no information at all
# metoprolol succinate,metoprolol succinate 1 dose (morning),toprol xl,metoprolol succinate toprol xl,metoprolol succinate 1 dose (morning)
# toprol xl, tamsulosin
# trileptal, trileptal 2 tabs with no further information, trileptal oxcarbazepine, antidepressant, ssris, penicillin, acetaminophen, acetaminophen 325mg, acetaminophen 325mg tab, acetaminophen 325mg tab 2 tabs with no further information, acetaminophen paracetamol
# trileptal, trileptal oxcarbazepine, penicillin, acetaminophen, acetaminophen paracetamol, no information at all
# isosorbide mononitrate, imdur, beta blockers, cardiac selective, medication for depression, medication for insomnia
# imdur,imdur,imdur,imdur,tramadol,ultram,beta blockers,imdur,imdur,tramadol,ultram,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,ultram,imdur,imdur,imdur,imdur,tramadol,
# mirtazapine, mirtazapine 30mg, carbamazepine, carbamazepine, painkillers, no information at all
# carbamazepine, carbamazepine, mirtazapine, mirtazapine
# carvedilol,carvedilol,ace inhibitors,carvedilol, no information at all,tamsulosin,carvedilol
# carvedilol, tamsulosin
# pravastatin, pravastatin for cholesterol, cefazolin, cefazolin antibiotic, cefazolin administered in the ambulance
# cefazolin, pravastatin, aspirin, paracetamol, antihistamine, no information at all
# acetaminophen,acetaminophen-caff-buta,caff-buta,pravachol,statins
# acetaminophen,acetaminophen-caff-buta,cafferine,pravastatin,no information at all
# isosorbide mononitrate, imdur, enalapril maleate, beta blockers cardiac selective, no information at all
# enapril maleate, enapril, isosorbide mononitrate, imdur, no information at all
# acetaminophen,acetaminophen-caff-buta,acetaminophen-caff-buta,caff-butalbital,caff-butalbital,caff-butalbital, butalbital
# suboxone,suboxone
# penicillin,penicillin
# acetaminophen-caff-buta,acetaminophen,caff-butalbital,no information at all
# prevacid (lansoprazole), prevacid, lansoprazole, albuterol inhaler, albuterol
# albuterol, albuterol sulfate, albuterol
# prevacid, prevacid, lansoprazole
# no information at all
# aspirin, bayer, salicylate analgesics, ceftriaxone, mini bag plus, antibiotic
# ceftriaxone, aspirin
# aspirin,acetaminophen,acetaminophen with codeine,codeine,simvastatin,no information at all
# acetaminophen w/codeine, acetaminophen, codeine, simvastatin
# gabapentin, no information at all, lactulose
# gabapentin, lactulose
# amlodipine,levofloxacin
# levofloxacin, amlodipine, no information at all
# lantus solostar u-100 insulin, insulin, anticoagulants, lactulose, no information at all
# insulin, lantus solostar u-100, lactulose, anticoagulants.
# acetaminophen,acetaminophen-caff-buta,caff-buta
# sucralfate
# sucralfate, sucralfate, acetaminophen, acetaminophen, caffeine, butalbital, sucralfate, sucralfate, acetaminophen, caffeine, butalbital, no information at all
# paracetamol,imdur,isosorbide mononitrate,2 tabs with no further information,oxycodone sr,oxycodone,penicillin,penicillin no information at all
# oxycodone, paracetamol, acetaminophen, imdur, isosorbide mononitrate, no information at all
# simvastatin, hmg coa reductase inhibitors, antihyperlipidemic, no information at all
# simvastatin, fentanyl
# albuterol, albuterol sulfate, ventolin, ampicillin-sulbactam, ampicillin, sulbactam
# ampicillin-sulbactam, ampicillin-sulbactam, ampicillin, sulbactam, albuterol sulfate, albuterol sulfate, albuterol
# lipitor, atorvastatin, atorvastatin 500mg, 500mg lipitor, no information at all
# levetiracetam, levetiracetam, levetiracetam tablets, levetiracetam 500mg tablets, lipitor, atorvastatin
# hydrocodone-acetaminophen, hydrocodone-acetaminophen, prenatal vitamins, prenatal vitamins, fa brand, no information at all
# hydrocodone-acetaminophen, hydrocodone-acetaminophen, hydrocodone, acetaminophen, hydrocodone acetaminophen, prenatal vitamin and minerals, prenatal vitamin and minerals, prenatal vitamin, minerals, prenatal vitamin and minerals, fa
# metoprolol succinate, beta blockers, cardiac selective, no information at all
# cefePIME, cefepime, metoprolol succinate, metoprolol, no information at all
# famotidine, metoprolol succinate,toprol xl, asthma, no information at all
# famotidine, metoprolol succinate, toprol xl
# clonidine, alprazolam, clonidine 1mg tab, alprazolam 1mg tab, no information at all
# alprazolam, alprazolam 0.5mg, clonidine, clonidine 0.1mg
# warfarin, clopidogrel, plavix, platelet aggregation inhibitors, thienopyridine agents, platelet jane, no information at all
# clopidogrel, warfarin, cefazolin
# dulera, dulera (inhaler), formoterol, mometasone
# morphine, morphine (ambulance crew), morphine sulfate
# metoclopramide, metoclopramide (ambulance crew), metoclopramide hydrochloride
# no information at all
# dulera, dulera (mometasone/formoterol), metoclopramide, morphine, morphine sulfate, no information at all
# vitamin d2, no information at all
# acetaminophen, paracetamol
# vitamin d2, ergocalciferol
# ascorbic acid, vitamin c
# ampicillin-su, ampicillin, isosorbide mononitrate, beta blockers cardiac selective, over the counter antibiotics, no information at all
# ampicillin, ampicillin sodium, isosorbide mononitrate, no information at all
# ibuprofen, rosuvastatin, lactulose, aspirin 1 tablet, paracetamol, antihistamine
# rosuvastatin, rosuvastatin calcium, ibuprofen, lactulose
# albuterol, albuterol sulfate, beta 2 adrenergic agent, short acting, dexamethasone, dexamethasone 10mg, dexamethasone 1ml vial, no information at all
# albuterol, albuterol sulfate, dexamethasone, no information at all
# omeprazole, omeprazole, propofol
# omeprazole, propofol, aspirin, paracetamol, antihistamine, no information at all
# aspirin, methadone
# aspirin, aspirin low dose, methadone, paracetamol, antihistamine
# diovan, diovan hct, valsartan, valsartan hctz, diovan, diovan hct, valsartan, valsartan hctz, oxycodone, oxycodone immediate release, aspirin 1 tablet with no further information, paracetamol with no further information, antihistamine with no further information
# oxycodone, diovan, no information at all
# pravachol, pravachol (hmg coa reductase inhibitor), pravachol (statin), pravachol, no information at all, readi-cat 2, readi-cat 2 (nausea medication), nausea medication
# pravachol, pravachol, pravastatin
# readi-cat 2, readi-cat 2 with no further information
# aspirin, aspirin x mg
# paracetamol
# antihistamine
#
# The relevant drugs extracted from the text are: pravachol, pravastatin, readi-cat 2, aspirin, paracetamol, antihistamine.
# Lisinopril, Lisinopril 25mg tab, Simvastatin, Amitriptyline 25mg tab, Amitriptyline - no information at all
# amitriptyline, amitriptyline 25mg, amitriptyline tab, lisinopril, simvastatin, simvastatin 2 tabs with no further information
# prevacid, prevacid, acetaminophen w codeine, acetaminophen w codeine, acetaminophen, codeine, tylenol, tylenol, advil, advil
# codeine, acetaminophen, paracetamol, prevacid
# aspirin, aspirin 1 tablet, aspirin tablets, aspirin (salicylate analgesics), salicylate analgesics, penicillin, penicillin (allergic)
# aspirin, nitroglycerin, no information at all
# acetaminophen with codeine, codeine, hydromorphone, acetaminophen
# acetaminophen with codeine, codeine, acetaminophen, hydromorphone, nsaids, no information at all
# combivir, no information at all
# combivir, lamivudine, zidovudine, norepinephrine, no information at all
# rivastigmine tartrate, rivastigmine, rivastigmine tartrate, hydrocodone-acetaminophen, hydrocodone, acetaminophen, no information at all
# hydrocodone, hydrocodone-acetaminophen, rivastigmine tartrate, acetaminophen
# lamictal, lamictal, lamotrigine, mirtazapine, mirtazapine, opioid withdrawal medication, opioid withdrawal medication, blood pressure medication, blood pressure medication, antipsychotic, antipsychotic, no information at all
# lamictal, lamictal, lamotrigine, mirtazapine, mirtazapine, nitroglycerin, nitroglycerin, oxygen, oxygen
# ibuprofen,acetaminophen,lansoprazole,fentanyl,acetaminophen,ibuprofen,over the counter painkillers,lansoprazole,ibuprofen,acetaminophen,over the counter painkillers,no information at all
# ibuprofen, ibuprofen 400mg, acetaminophen, acetaminophen 500mg, fentanyl, fentanyl patch, lansoprazole, lansoprazole 30mg
# rosuvastatin, rosuvastatin, statin, hydrocodone, dilaudid, hydromorphone, no information at all
# hydromorphone, hydromorphone, rosuvastatin, rosuvastatin
# ibuprofen, simvastatin, statins, no information at all
# midazolam, simvastatin
# buspirone,calcium channel blockers,dihydropyridines,ampicillin-sulbactam,ampicillin-sulbactam 100ml bag,ampicillin-sulbactam with no further information
# ampicillin, ampicillin-su, buspirone, calcium channel blockers, dihydropyridines
# prilosec, prilosec omeprazole,
# sodium, sodium,
# no information at all
# levothyroxine sodium, levothyroxine, prilosec, omeprazole, no information at all
# simvastatin, atorvastatin, atorvastatin 40mg, no information at all
# atorvastatin, simvastatin
# rosuvastatin,rosuvastatin,crestor,
# penicillin,penicillin,allergy,
# sulfa drugs,sulfa drugs,allergy,
# magnesium sulfate,magnesium sulfate,administered in the ambulance,
# no information at all
# magnesium sulfate, rosuvastatin, crestor, no information at all
# metoprolol tartrate, metoprolol, beta blockers cardiac selective; vancomycin, vancomycin; no information at all
# metoprolol, vancomycin
# lamotrigine, lamotrigine 1 answer 56 views 0 helpful votes 0 comments 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges 0 followers 0 questions 0 answers 0 edits 0 points 0 badges, bisoprolol fumarate, bisop
# lamotrigine, bisoprolol, no information at all
# lamotrigine, lamoTRIgine, lamotrigine tablet, lamotrigine 2 tabs with no further information, finasteride
# lamotrigine, lamotrigine 25mg, antibiotics, pain relief, finasteride, finasteride 5mg
# metoprolol tartrate, metoprolol, beta blockers cardiac selective, lactulose, lactulose
# metoprolol tartrate, metoprolol, lactulose, no information at all
# pravastatin, aspirin, aspirin ec, acetylsalicylic acid, no information at all
# aspirin ec, aspirin, tpa, pravastatin
# bisoprolol fumarate, bisoprolol fumarate for heart condition, bisoprolol, acetaminophen 500mg TAB, acetaminophen 500mg TAB twice, acetaminophen
# acetaminophen,acetaminophen 500mg,acetaminophen tab,acetaminophen tab 500mg,bisoprolol fumarate,no information at all
# rivastigmine tartrate, beta blockers cardiac selective, pantoprazole sodium
# rivastigmine tartrate, rivastigmine, Pantoprazole Sodium, pantoprazole, insulin
# aspirin, bayer aspirin, salicylate analgesics, acetaminophen, paracetamol, no information at all
# aspirin, aspirin, acetaminophen, acetaminophen, no information at all
# lovastatin,lovastatin 1 tablet,lovastatin without further information
# lovastatin, tetanus, diphtheria toxoid, acellular pertussis vaccine, no information at all
# atorvastatin 40mg tab,atorvastatin,rosuvastatin,birth control pills, no information at all
# atorvastatin, rosuvastatin, birth control pills, penicillin allergy, no information at all
# isordil, isosorbide mononitrate, beta blockers cardiac selective, metronidazole, flagyl, asthma medication, bronchodilator, no information at all
# flagyl, isosorbide mononitrate, beta blockers cardiac selective, no information at all
# milk of magnesia, milk of magnesia, antacid
# nsaid analgesics, nsaid analgesics, generic
# clindamycin, clindamycin
# cox non-specific propionic acid medication, cox non-specific propionic acid medication, generic
# cox non-specific propionic acid derivatives, cox non-specific propionic acid derivatives, generic
# magnesia, magnesia hydroxide, clindamycin, aspirin, paracetamol, antihistamine
# suboxone, methadone, methadone dispersible tablet, penicillin, penicillin allergy
# suboxone, methadone
# toprol xl, toprol xl, metoprolol, oxycodone-acetaminophen, oxycodone-acetaminophen, oxycodone, morphine, morphine
# oxycodone-acetaminophen, oxycodone, acetaminophen, toprol xl, morphine

# %%
processed_df.head(1)
# Out:
#    json_i                       _id        question  \
# 0       0  669933e4afbfd9c3c2d8efd0  chiefcomplaint
#
#                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
#
#                                      data Class  \
# 0  Lower back pain, L Knee pain, Headache
#
#                                                          data_gpt  \
# 0  [lower back pain, l knee pain, headache, knee pain, head pain]
#
#                                                                                    answer_gpt
# 0  [lower back pain, knee pain, headache, trouble sleeping, affecting mood and energy levels]

# %% [raw]
# filtered_df = processed_df_medication_answer.loc[processed_df_medication_answer['question'].isin(['medication_reported', 'medication_pyxis'])].copy()
# filtered_df.head(30)

# %%
# Save to CSV or handle the DataFrame as needed
processed_df.to_csv('processed_df-completeGpt.csv', index=False)

# %%
#CHECK THE isnull, to see if postprocessing with gpt did work


# Check for empty cells in the DataFrame
empty_cells = processed_df.isnull() | (processed_df.applymap(lambda x: len(x) == 0 if isinstance(x, list) else False))

# Get rows with any empty cells
rows_with_empty_cells = processed_df[empty_cells.any(axis=1)]

# Get unique questions from those rows
unique_questions_with_empty_cells = rows_with_empty_cells['question'].unique()

# Print the unique questions
print('Those question where not affected by gpt postprocessing ')
print(unique_questions_with_empty_cells)
# Out:
# Those question where not affected by gpt postprocessing
# ['bp' 'heartrate' 'o2sat_triage' 'resprate' 'temperature' 'pain_triage']
# /tmp/ipykernel_5565/2768088682.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   empty_cells = processed_df.isnull() | (processed_df.applymap(lambda x: len(x) == 0 if isinstance(x, list) else False))

# %% [markdown]
# ## Classification of nominals by cosine_similarity between gpt-postprocessed data and answers:

# %%
processed_df_done = processed_df

# %%
import torch
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the BlueBERT tokenizer and model for embeddings
model_name = 'bionlp/bluebert_pubmed_mimic_uncased_L-12_H-768_A-12'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModel.from_pretrained(model_name)

# %%
def compute_embeddings(text):
    text = text.lower()  # Convert text to lowercase
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

def classify_nominals(df):
    classifications = []
    all_similarities = []
    cutoff_positive = 0.85
    cutoff_negative = 0.6  # Average cutoff for FN
    
    for index, row in df.iterrows():
        data_gpt_csv_embeddings = [compute_embeddings(item) for item in row['data_gpt']]
        answer_gpt_csv_embeddings = [compute_embeddings(item) for item in row['answer_gpt']]
        
        row_classification = "FP"
        row_similarities = []
        for data_embedding in data_gpt_csv_embeddings:
            max_similarity = 0
            for answer_embedding in answer_gpt_csv_embeddings:
                similarity = cosine_similarity([data_embedding], [answer_embedding])[0][0]
                row_similarities.append(similarity)
                if similarity > max_similarity:
                    max_similarity = similarity
                if similarity >= cutoff_positive:
                    row_classification = "TP"
                    break
            if row_classification == "TP":
                break
        
        # Calculate the average similarity score
        average_similarity = sum(row_similarities) / len(row_similarities) if row_similarities else 0
        if row_classification == "FP" and average_similarity <= cutoff_negative:
            row_classification = "FN"
        
        classifications.append(row_classification)
        all_similarities.append(row_similarities)
    
    df['Class'] = classifications
    df['Similarities'] = all_similarities
    return df

# %%
def compute_classification_metrics(df, question_types):
    """
    Filters the DataFrame for specified question types and computes classification metrics.

    Parameters:
    df (pd.DataFrame): The input DataFrame containing the classification results.
    question_types (list): List of question types to filter the DataFrame.

    Returns:
    dict: A dictionary containing question types, TP count, FP count, FN count, precision, recall, and F1-score.
    """
    # Filter the DataFrame to only include rows with the specified question types
    filtered_df = df[df['question'].isin(question_types)]

    # Calculate counts for TP, FP, FN
    tp_count = (filtered_df['Class'] == 'TP').sum()
    fp_count = (filtered_df['Class'] == 'FP').sum()
    fn_count = (filtered_df['Class'] == 'FN').sum()

    # Calculate Precision, Recall, and F1-score
    precision = tp_count / (tp_count + fp_count) if (tp_count + fp_count) > 0 else 0
    recall = tp_count / (tp_count + fn_count) if (tp_count + fn_count) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    # Round the precision, recall, and F1-score to 2 decimal places
    precision = round(precision, 2)
    recall = round(recall, 2)
    f1_score = round(f1_score, 2)

    # Create a dictionary with the results
    metrics = {
        'Question_types': question_types,
        'TP_count': tp_count,
        'FP_count': fp_count,
        'FN_count': fn_count,
        'Precision': precision,
        'Recall': recall,
        'F1_score': f1_score
    }

    return metrics

# %%
# UTILITY METHODS

import ast
import pandas as pd
import matplotlib.pyplot as plt
import os




def sort_to_lastscore(df, cls='TP', order='asc', questions=None):
    """
    Filter the DataFrame for a specific class and questions, and sort by the last score.

    Parameters:
    df (pd.DataFrame): The input DataFrame.
    cls (str): The class to filter by.
    order (str): The sort order ('asc' for ascending, 'desc' for descending).
    questions (list or str): The questions to filter by ('all' for all relevant questions).

    like:
    sorted_df = sort_to_lastscore(df, cls='TP', order='asc', questions=['chiefcomplaint', 'medication_reported'])
    sorted_df = sort_to_lastscore(df, cls='TP', order='asc', questions='all')

    Returns:
    pd.DataFrame: The sorted copy of the DataFrame.
    """
    if questions == 'all':
        questions = ['chiefcomplaint', 'medication_reported', 'medication_pyxis', 'diagnosis']
    elif isinstance(questions, str):
        questions = [questions]

    # Filter the DataFrame for the specified class and questions
    filtered_df = df[(df['Class'].str.upper() == cls.upper()) & (df['question'].isin(questions))]

    # Sort the DataFrame by 'last_score'
    sorted_df = filtered_df.copy().sort_values(by='last_score', ascending=(order == 'asc'))
    
    return sorted_df




def add_last_score_to_all_nominals(df):
    """
    Extract the last score from the 'Similarities' column for every row and insert it into a new column 'last_score'.

    Parameters:
    df (pd.DataFrame): The input DataFrame.

    Returns:
    pd.DataFrame: The DataFrame with an additional 'last_score' column.
    """
    def extract_last_score(similarities):
        try:
            # Convert the string representation to an actual list
            similarities_list = ast.literal_eval(similarities)
            # Return the last item of the list
            return similarities_list[-1] if similarities_list else float('nan')
        except (ValueError, SyntaxError):
            return float('nan')
    
    # Apply the function to extract the last score
    df['last_score'] = df['Similarities'].apply(extract_last_score)
    
    return df


def add_last_score_to_all_nominals(df):
    """
    Extract the last score from the 'Similarities' column for every row and insert it into a new column 'last_score'.

    Parameters:
    df (pd.DataFrame): The input DataFrame.

    Returns:
    pd.DataFrame: The DataFrame with an additional 'last_score' column.
    """
    def extract_last_score(similarities):
        try:
            # Convert the string representation to an actual list
            similarities_list = ast.literal_eval(similarities)
            # Return the last item of the list
            return similarities_list[-1] if similarities_list else float('nan')
        except (ValueError, SyntaxError):
            return float('nan')
    
    # Apply the function to extract the last score
    df['last_score'] = df['Similarities'].apply(extract_last_score)
    
    return df


def add_last_score_to_all_nominals(df):
    """
    Extract the last score from the 'Similarities' column for every row and insert it into a new column 'last_score'.

    Parameters:
    df (pd.DataFrame): The input DataFrame.

    Returns:
    pd.DataFrame: The DataFrame with an additional 'last_score' column.
    """
    def extract_last_score(similarities):
        if isinstance(similarities, list):
            return similarities[-1] if similarities else float('nan')
        return float('nan')
    
    # Apply the function to extract the last score
    df['last_score'] = df['Similarities'].apply(extract_last_score)
    
    return df




def plot_classification_scores(df, questions=None, cutoff=0.85):
    """
    Plot a scatter plot of classification scores with a cutoff line.

    Parameters:
    df (pd.DataFrame): The input DataFrame.
    questions (list or str): The questions to filter by ('all' for all relevant questions).
    cutoff (float): The cutoff line for the scores.
    """
    if questions == 'all':
        questions = ['chiefcomplaint', 'medication_reported', 'medication_pyxis', 'diagnosis']
    elif isinstance(questions, str):
        questions = [questions]

    # Filter the DataFrame for the specified questions
    filtered_df = df[df['question'].isin(questions)].copy()

    # Define markers and colors for each question and class
    question_markers = {
        'chiefcomplaint': 'o',
        'medication_reported': 's',
        'medication_pyxis': '^',
        'diagnosis': 'D'
    }

    class_colors = {
        'TP': 'green',
        'FP': 'darkorange',
        'FN': 'red'
    }

    # Plot the scatter plot
    plt.figure(figsize=(10, 6))
    for question in questions:
        question_df = filtered_df[filtered_df['question'] == question]
        plt.scatter(
            question_df['json_i'], 
            question_df['last_score'], 
            label=question, 
            marker=question_markers.get(question, 'o'), 
            c=question_df['Class'].map(class_colors),
            edgecolor='k',
            s=100
        )
    
    # Plot the cutoff line
    plt.axhline(y=cutoff, color='blue', linestyle='--', label=f'Cutoff = {cutoff}')
    
    # Add labels and legend
    plt.xlabel('Index')
    plt.ylabel('Last Score')
    plt.title('Classification Scores with Cutoff Line')
    plt.legend(title='Questions')
    plt.grid(True)
    plt.show()





def load_csv_to_df(file_name):
    """
    Load a CSV file into a Pandas DataFrame.

    Parameters:
    file_name (str): The name of the CSV file to load.

    Returns:
    pd.DataFrame: The loaded DataFrame.
    """
    # Get the current working directory
    current_dir = os.getcwd()
    
    # Construct the file path
    file_path = os.path.join(current_dir, file_name)
    
    # Load the CSV file into a DataFrame
    df = pd.read_csv(file_path)
    
    return df

    

def find_specific_rows_with_only_one_arrayitem(df, column_name, target_array):
    """
    Find rows where the specified column contains exactly the target array.

    Parameters:
    df (pd.DataFrame): The DataFrame to search.
    column_name (str): The column to search within.
    target_array (list): The array to match.

    Returns:
    pd.DataFrame: The DataFrame with matching rows.
    """
    # Define a function to check if the column value matches the target array
    def matches_target(value):
        try:
            # Convert the string representation to an actual list
            value_list = ast.literal_eval(value)
            return value_list == target_array
        except (ValueError, SyntaxError):
            return False
    
    # Find rows where the column matches the target array
    matching_rows = df[df[column_name].apply(matches_target)]
    
    return matching_rows

# Example usage if df is to be loaded from a csv that contains allready gpt preprocessing for nominals, if not done here
#classified_df = load_csv_to_df('df_nominal_classified-de.csv')
#classified_df = load_csv_to_df('df_nominal_classified-de.csv')
#classified_df.head(10)

# %% [markdown]
# #### classification with embeddings ______

# %%
# Classification into TP, FP, FN with COS.


classified_df = classify_nominals(processed_df)

# %% [markdown]
# #### Check for FN ['no information at all']______

# %%
matching_rows = find_specific_rows_with_only_one_arrayitem(classified_df, 'answer_gpt', ['no information at all'])
matching_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   json_i        0 non-null      int64
#  1   _id           0 non-null      object
#  2   question      0 non-null      object
#  3   answer        0 non-null      object
#  4   data          0 non-null      object
#  5   Class         0 non-null      object
#  6   data_gpt      0 non-null      object
#  7   answer_gpt    0 non-null      object
#  8   Similarities  0 non-null      object
# dtypes: int64(1), object(8)
# memory usage: 0.0+ bytes

# %%
matching_rows.head(1)
# Out:
# Empty DataFrame
# Columns: [json_i, _id, question, answer, data, Class, data_gpt, answer_gpt, Similarities]
# Index: []

# %%
# nach inspektion mussten unter answer_gpt alle mit 'no information at all' von hand auf FN gesetzt werden, da kein cutoff gesetzt werden kann der klar ist. war bei en-dialogen nicht aufgefallen da sehr wenige.
df_copysave = classified_df.copy()
classified_df.loc[classified_df['answer_gpt'].apply(lambda x: ast.literal_eval(x) == ['no information at all']), 'Class'] = 'FN'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 # nach inspektion mussten unter answer_gpt alle mit 'no information at all' von hand auf FN gesetzt werden, da kein cutoff gesetzt werden kann der klar ist. war bei en-dialogen nicht aufgefallen da sehr wenige.
#       2 df_copysave = classified_df.copy()
# ----> 3 classified_df.loc[classified_df['answer_gpt'].apply(lambda x: ast.literal_eval(x) == ['no information at all']), 'Class'] = 'FN'
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/site-packages/pandas/core/series.py:4915, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4780 def apply(
#    4781     self,
#    4782     func: AggFuncType,
#    (...)
#    4787     **kwargs,
#    4788 ) -> DataFrame | Series:
#    4789     """
#    4790     Invoke function on values of Series.
#    4791
#    (...)
#    4906     dtype: float64
#    4907     """
#    4908     return SeriesApply(
#    4909         self,
#    4910         func,
#    4911         convert_dtype=convert_dtype,
#    4912         by_row=by_row,
#    4913         args=args,
#    4914         kwargs=kwargs,
# -> 4915     ).apply()
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[38], line 3, in <lambda>(x)
#       1 # nach inspektion mussten unter answer_gpt alle mit 'no information at all' von hand auf FN gesetzt werden, da kein cutoff gesetzt werden kann der klar ist. war bei en-dialogen nicht aufgefallen da sehr wenige.
#       2 df_copysave = classified_df.copy()
# ----> 3 classified_df.loc[classified_df['answer_gpt'].apply(lambda x: ast.literal_eval(x) == ['no information at all']), 'Class'] = 'FN'
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File ~/miniconda3/envs/aidocs/lib/python3.11/ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string: ['lower back pain', 'knee pain', 'headache', 'trouble sleeping', 'affecting mood and energy levels']

# %% [markdown]
# #### Calculate Metrics______

# %%
def save_metrics_as_json(metrics, question_types):
    # Function to convert numpy data types to Python native types for JSON serialization
    def convert(o):
        if isinstance(o, np.int64): return int(o)  
        raise TypeError
    
    # Generate the file name based on the given question types
    file_name = "metrics_nominal-" + "_".join(question_types) + ".json"
    
    # Convert the metrics dictionary to a JSON string, using the convert function for non-serializable types
    metrics_json = json.dumps(metrics, indent=4, default=convert)
    
    # Write the JSON string to a file with the dynamically generated name
    with open(file_name, 'w') as file:
        file.write(metrics_json)
    
    print(f"Metrics saved to {file_name}")

# %%
# Specify the question types to filter
question_types = ['chiefcomplaint', 'diagnosis', 'medication_reported', 'medication_pyxis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-chiefcomplaint_diagnosis_medication_reported_medication_pyxis.json
# {'Question_types': ['chiefcomplaint',
#   'diagnosis',
#   'medication_reported',
#   'medication_pyxis'],
#  'TP_count': 353,
#  'FP_count': 42,
#  'FN_count': 1,
#  'Precision': 0.89,
#  'Recall': 1.0,
#  'F1_score': 0.94}

# %%
# Specify the question types to filter
question_types = ['chiefcomplaint', 'diagnosis', 'medication_reported', 'medication_pyxis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-chiefcomplaint_diagnosis_medication_reported_medication_pyxis.json
# {'Question_types': ['chiefcomplaint',
#   'diagnosis',
#   'medication_reported',
#   'medication_pyxis'],
#  'TP_count': 353,
#  'FP_count': 42,
#  'FN_count': 1,
#  'Precision': 0.89,
#  'Recall': 1.0,
#  'F1_score': 0.94}

# %%
# Specify the question types to filter
question_types = ['chiefcomplaint', 'diagnosis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-chiefcomplaint_diagnosis.json
# {'Question_types': ['chiefcomplaint', 'diagnosis'],
#  'TP_count': 161,
#  'FP_count': 36,
#  'FN_count': 1,
#  'Precision': 0.82,
#  'Recall': 0.99,
#  'F1_score': 0.9}

# %%
# Specify the question types to filter
question_types = ['medication_reported', 'medication_pyxis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-medication_reported_medication_pyxis.json
# {'Question_types': ['medication_reported', 'medication_pyxis'],
#  'TP_count': 192,
#  'FP_count': 6,
#  'FN_count': 0,
#  'Precision': 0.97,
#  'Recall': 1.0,
#  'F1_score': 0.98}

# %%
# Specify the question types to filter
question_types = ['diagnosis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-diagnosis.json
# {'Question_types': ['diagnosis'],
#  'TP_count': 86,
#  'FP_count': 13,
#  'FN_count': 0,
#  'Precision': 0.87,
#  'Recall': 1.0,
#  'F1_score': 0.93}

# %%
# Specify the question types to filter
question_types = ['chiefcomplaint']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-chiefcomplaint.json
# {'Question_types': ['chiefcomplaint'],
#  'TP_count': 75,
#  'FP_count': 23,
#  'FN_count': 1,
#  'Precision': 0.77,
#  'Recall': 0.99,
#  'F1_score': 0.86}

# %%
# Specify the question types to filter
question_types = ['medication_reported']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-medication_reported.json
# {'Question_types': ['medication_reported'],
#  'TP_count': 97,
#  'FP_count': 2,
#  'FN_count': 0,
#  'Precision': 0.98,
#  'Recall': 1.0,
#  'F1_score': 0.99}

# %%
# Specify the question types to filter
question_types = ['medication_pyxis']
# Compute the classification metrics
metrics = compute_classification_metrics(classified_df, question_types)
save_metrics_as_json(metrics, question_types)
metrics
# Out:
# Metrics saved to metrics_nominal-medication_pyxis.json
# {'Question_types': ['medication_pyxis'],
#  'TP_count': 95,
#  'FP_count': 4,
#  'FN_count': 0,
#  'Precision': 0.96,
#  'Recall': 1.0,
#  'F1_score': 0.98}

# %%
# Save to CSV or handle the DataFrame as needed
classified_df.to_csv('df_nominal_classified.csv', index=False)

# %% [markdown]
# # Inspection

# %%
classified_df.head(1)

# %%
# Check the Class and Scores to see if the Set cutoff is ok
classified_df_lastscored= add_last_score_to_all_nominals(classified_df)
classified_df_lastscored.head(2)
# Out:
#    json_i                       _id             question  \
# 0       0  669933e4afbfd9c3c2d8efd0       chiefcomplaint
# 1       0  669933e4afbfd9c3c2d8efd0  medication_reported
#
#                                                                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0                                                  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
# 1  1. Acetaminophen 325mg TAB\n2. OxyContin (Oxycodone)\n3. Two 10mg tablets of an unknown medication (assumed to be a pain medication, possibly a generic or brand name of Oxycodone) taken in the morning.\n-------\nPlease extract every single pharmaceuticals, drugs and medications that the patient says he has taken or is taking as a list, like: Aspirin 1 tablet; Paracetamol; Antihistamine!
#
#                                      data Class  \
# 0  Lower back pain, L Knee pain, Headache    TP
# 1                   oxycodone [OxyContin]    TP
#
#                                                          data_gpt  \
# 0  [lower back pain, l knee pain, headache, knee pain, head pain]
# 1                     [oxycodone oxycontin, oxycodone, oxycontin]
#
#                                                                                    answer_gpt  \
# 0  [lower back pain, knee pain, headache, trouble sleeping, affecting mood and energy levels]
# 1                       [acetaminophen, oxycodone, unknown medication, no information at all]
#
#               Similarities  last_score
# 0                    [1.0]    1.000000
# 1  [0.6656809, 0.93377674]    0.933777

# %%
plot_classification_scores(classified_df_lastscored, questions='all')
# Save the plot as a PNG file
questions_str = '_'.join(['all'])
filename = f'nominal_score_cutoff_{questions_str}.png'
plt.savefig(filename, bbox_inches='tight')
print(f'Plot saved as {filename}')
# Out:
# Plot saved as nominal_score_cutoff_all.png

# %%
plot_classification_scores(classified_df_lastscored, questions='chiefcomplaint')
questions_str = '_'.join(['chiefcomplaint'])
filename = f'nominal_score_cutoff_{questions_str}.png'
plt.savefig(filename, bbox_inches='tight')
print(f'Plot saved as {filename}')
# Out:
# Plot saved as nominal_score_cutoff_chiefcomplaint.png

# %%
plot_classification_scores(classified_df_lastscored, questions='medication_reported')
questions_str = '_'.join(['medication_reported'])
filename = f'nominal_score_cutoff_{questions_str}.png'
plt.savefig(filename, bbox_inches='tight')
print(f'Plot saved as {filename}')
# Out:
# Plot saved as nominal_score_cutoff_medication_reported.png

# %%
plot_classification_scores(classified_df_lastscored, questions='medication_pyxis')
questions_str = '_'.join(['medication_pyxis'])
filename = f'nominal_score_cutoff_{questions_str}.png'
plt.savefig(filename, bbox_inches='tight')
print(f'Plot saved as {filename}')
# Out:
# Plot saved as nominal_score_cutoff_medication_pyxis.png

# %%
plot_classification_scores(classified_df_lastscored, questions='diagnosis')
questions_str = '_'.join(['diagnosis'])
filename = f'nominal_score_cutoff_{questions_str}.png'
plt.savefig(filename, bbox_inches='tight')
print(f'Plot saved as {filename}')
# Out:
# Plot saved as nominal_score_cutoff_diagnosis.png

# %%
# Inspect if the lower TP are still reasonable and confirming the set cutoff, or that cutoff must be changed.
#sorted_df_tp = sort_to_lastscore(classified_df_lastscored, cls='TP', order='asc', questions=['chiefcomplaint', 'medication_reported'])
#sorted_df_fp = sort_to_lastscore(classified_df_lastscored, cls='FP', order='desc', questions='all')
#sorted_df_fp = sort_to_lastscore(classified_df_lastscored, cls='FP', order='desc', questions=['diagnosis'])


sorted_df_fp_diagnosis = sort_to_lastscore(classified_df_lastscored, cls='FP', order='desc', questions=['diagnosis'])
sorted_df_fp_diagnosis.head(10)
# Out:
#      json_i                       _id   question  \
# 963      96  66992716d1743c934ee2530d  diagnosis
# 403      40  66994e5bafbfd9c3c2d8eff5  diagnosis
# 333      33  66995ef0afbfd9c3c2d8f00b  diagnosis
# 233      23  66992865d1743c934ee2530f  diagnosis
# 933      93  669949a6afbfd9c3c2d8efee  diagnosis
# 693      69  6699696dafbfd9c3c2d8f01a  diagnosis
# 73        7  6699391fafbfd9c3c2d8efd7  diagnosis
# 663      66  6699604cafbfd9c3c2d8f00d  diagnosis
# 473      47  66994568afbfd9c3c2d8efe8  diagnosis
# 193      19  669a3497b28427e498d63ccc  diagnosis
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    answer  \
# 963                                                                                    • Fall-related injury to the left foot\n• Pain\n• Infection (suspected, antibiotic administered)\n• Inflammation (mentioned as a possible cause of pain)\n• Possible fracture or other internal injury (not explicitly stated, but implied by the patient's pain and the need for medical attention)\n• Possible soft tissue injury (not explicitly stated, but implied by the patient's pain and the need for medical attention)\n• Hypertension (blood pressure 150 over 88, but not explicitly stated as a diagnosis)\n• Tachycardia (heart rate 98, then 88 beats per minute, but not explicitly stated as a diagnosis)\n• Tachypnea (respiratory rate 14, then 17 breaths per minute, but not explicitly stated as a diagnosis)\n• Fever (temperature 100.5 degrees Fahrenheit, but not explicitly stated as a diagnosis)\n• Possible internal bleeding or hematoma (not explicitly stated, but implied by the patient's pain
# 403                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         • Severe abdominal pain\n• Intense or violent thoughts (considered as a possibility)\n• Unknown cause of pain\n• Possible medication side effect (not specified which one)\n• Possible medication overdose (not specified which one)\n• Unknown medication (patient can't remember the name)\n• Unknown medication interaction (patient is taking multiple medications)\n• Unknown underlying condition (patient's pain is worsening)  END OF
# 333                                                                                                                                          - Trauma (from the fall)\n- Possible broken leg (from the fall)\n- Respiratory distress (from the fall)\n- Pain (from the fall)\n- Hypotension (low blood pressure)\n- Possible internal injuries (from the fall)\n- Possible head trauma (from the fall, not explicitly mentioned but implied)\n- Asthma (pre-existing condition, mentioned as managed with an inhaler)\n- Possible pulmonary edema (from the fall, implied by the doctor's mention of "we'll need to take a look at that leg, too")\n- Possible internal bleeding (from the fall, implied by the doctor's mention of "we'll need to take a look at that leg, too")\n- Possible pulmonary contusion (from the fall, implied by the doctor's mention of "we'll need to take a look at that leg, too")\n- Possible pneumothorax (from the fall, implied by the doctor's mention of "we'll need to take a look
# 803      80  66995485afbfd9c3c2d8effd  diagnosis
# 53        5  669a21c9e99958338bd863f1  diagnosis
# 883      88  66995897afbfd9c3c2d8f002  diagnosis
# 633      63  669965b1afbfd9c3c2d8f015  diagnosis
# 213      21  669952e1afbfd9c3c2d8effb  diagnosis
# 643      64  66994239afbfd9c3c2d8efe4  diagnosis
# 313      31  669a262fe99958338bd863f7  diagnosis
# 483      48  66993e3eafbfd9c3c2d8efde  diagnosis
# 443      44  669a2046e99958338bd863ef  diagnosis
# 503      50  669a257de99958338bd863f6  diagnosis
# 893      89  6699432cafbfd9c3c2d8efe5  diagnosis
# 123      12  669950bbafbfd9c3c2d8eff8  diagnosis
# 353      35  66996311afbfd9c3c2d8f011  diagnosis
# 373      37  6699673aafbfd9c3c2d8f017  diagnosis
# 513      51  6699646bafbfd9c3c2d8f013  diagnosis
# 393      39  6699460cafbfd9c3c2d8efe9  diagnosis
# 523      52  669a2acef4c382a406ceba49  diagnosis
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            answer  \
# 623                                                                                                                                                                    1. Head injury\n2. Pain\n3. Nausea\n4. Low blood pressure\n5. High pain level\n6. Hematoma (suspected)\n7. Fall-related injury\n8. Possible internal injuries (suspected)\n9. Cardiac arrest (ruled out)\n10. Possible spinal injury (suspected)\n11. Internal bleeding (suspected)\n12. Fracture (suspected)\n13. Concussion (suspected)\n14. Internal organ damage (suspected)\n15. Possible cardiac issues (ruled out)\n16. Vitals instability (mentioned, not a diagnosis)\n17. Respiratory distress (not mentioned)\n18. Neurological damage (suspected)\n19. Internal bleeding or hematoma in the brain (suspected)\n20. Possible spinal cord injury (suspected)\n21. Possible organ damage (suspected)\n22. Possible head trauma (suspected)\n23. Possible internal bleeding (suspected)\n24. Possible concussion (
# 903                                                                                                                                                                                                                                     1. Cardiac issue (Beta Blockers Cardiac Selective)\n2. Vaginal bleed\n3. Chest pain\n4. Shortness of breath\n5. Dizziness\n6. Weakness\n7. Possible Pulmonary Embolism (ADV EFF ANTINFCT NEC/NOS)\n8. Possible Myocardial Infarction (heart attack)\n9. Possible Cardiac Arrest\n10. Possible Pulmonary Embolism (again, as it was mentioned twice)\n11. Possible Hemorrhage (from vaginal bleed)\n\nPlease note that the patient's actual diagnosis is not known and the above list is based on the information provided in the context.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.
# 543                                                                1. High cholesterol\n2. Knee injury (twisted knee, possible fracture or dislocation)\n3. Pain (knee, 8/10)\n4. Respiratory distress (oxygen saturation 96%)\n5. Trauma (fall down the stairs)\n6. Unknown possible head or spine injury (no direct assessment, but patient fell down the stairs) 7. Unknown possible internal injuries (no direct assessment, but patient fell down the stairs) 8. Unknown possible spinal cord injury (no direct assessment, but patient fell down the stairs) 9. Unknown possible traumatic brain injury (no direct assessment, but patient fell down the stairs) 10. Unknown possible vertebral fracture or dislocation (no direct assessment, but patient fell down the stairs)\n-------\nContext information is below.\n-------\nrate is 70 beats per minute, respiratory rate is 15 breaths per minute, blood pressure is 137 over 88 millimeters of mercury, and your oxygen saturation
# 803                                                                                                                                                                                                          • Abdominal pain (RLQ)\n• Anemia (suspected)\n• Hemorrhage (considered)\n• Appendicitis (considered)\n• Intestinal obstruction (considered)\n• Gastrointestinal bleeding (considered)\n• Other abdominal pathology (considered)\n• Hypovolemic shock (considered)\n• Cardiac arrest (not assessed, but considered in the context of hypovolemic shock)\n• Hypovolemia (assessed, but not a diagnosis)\n• Pain (RLQ, intermittent, worsening) - symptom\n• Anemia (suspected, not a diagnosis) - condition\n• Hypotension (not assessed, but considered in the context of hypovolemic shock) - not a diagnosis\n• Shock (considered, not a diagnosis)\n• Hypovolemic shock (considered, not a diagnosis)\n• Hypovolemia (assessed, not a diagnosis) - condition\n• Anemia (suspected,
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                                            • Anemia\n• Underlying medical condition (general)\n• High blood pressure (pre-existing condition)\n• Possible cause of discomfort (general, not specific)\n• Pain (dull ache, radiating towards back)\n• Hematological disorder (suspected, based on symptoms)\n• Anemia (suspected, based on symptoms)\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single medication, treatment, or intervention mentioned in the conversation, like: morphine; defibrillator!
# 883                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            nausea and vomiting; dehydration; possible serious condition; possible gastrointestinal issue; possible infection; possible food poisoning; possible viral or bacterial infection; possible stomach bug; possible stomach flu; possible foodborne illness.  END OF
# 633                                                                                                              1. Abdominal pain\n2. Fever\n3. Sharp pain in the lower abdomen\n4. Unspecified infection or illness\n5. Potential internal injury or bleeding\n6. Potential surgical emergency\n7. Potential sepsis\n8. Potential appendicitis (considered, but not confirmed)\n9. Potential other abdominal pathology (considered, but not confirmed)\n10. Potential non-abdominal pathology (considered, but not confirmed)\n\nPlease note that the final diagnosis is not provided in the given context information. The above list represents the considered, suspected, or assessed medical conditions or diagnoses or injuries based on the conversation.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.
# 213                 • Dizziness\n• Fast heart rate\n• Pain (abdominal, unspecified)\n• Allergic reaction (bee sting, not relevant in this context)\n• Possible overdose or substance abuse (not explicitly stated, but implied by the doctor's question)\n• Possible anxiety or panic attack (not explicitly stated, but implied by the doctor's question)\n• Possible cardiac issue (suspected by the doctor)\n• Possible other medical condition or injury (suspected by the doctor, but not specified)\n• Possible psychological or psychiatric condition (suspected by the doctor, but not specified)\n• Possible medication side effect (suspected by the doctor, but not specified)\n• Possible other substance abuse (suspected by the doctor, but not specified)\n• Hypothermia (considered, but not confirmed, as the patient's temperature is 97.7°F, which is slightly low but not severely low)\n• Other (not specified, but the doctor is considering various possibilities)  END OF
# 393                                            1. Depression\n2. High blood pressure\n3. Dizziness\n4. Headache\n5. Sleep disturbance\n6. Prostate cancer (initially suspected, later clarified as not applicable due to patient being a woman)\n7. Unknown medical condition causing low mood and hopelessness\n8. Unknown medical condition causing physical symptoms (not specified) 9. Possible medication side effect (not specified)\n10. Possible medication interaction (not specified)\n\nPlease note that the patient's symptoms and the crew's observations are not necessarily a diagnosis, but rather a report of the patient's condition and the crew's findings. The actual diagnosis would be determined by a medical professional after a thorough examination and investigation.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer.  end of answer
# 523                                                                                                                       1. Contact wound from a knife\n2. Throat injury\n3. Pain in the throat\n4. Suspected laceration\n5. Suspected airway compromise\n6. Suspected bleeding in the throat\n7. Suspected trauma to the throat\n8. Possible removal of the object in the throat\n9. Possible laceration of the throat\n10. Possible airway compromise\n11. Possible bleeding in the throat\n12. Possible trauma to the throat\n13. Possible injury to the throat\n14. Possible throat injury\n15. Possible throat trauma\n16. Possible throat laceration\n17. Possible throat bleeding\n18. Possible throat pain\n19. Possible throat discomfort\n20. Possible throat swelling\n21. Possible throat trauma or injury\n22. Possible throat bleeding or laceration\n23. Possible throat trauma, bleeding, or laceration\n24. Possible throat trauma, bleeding, laceration, or pain\n25. Possible
#
#                                                         data Class  \
# 623  Oth intartic fracture of lower end of left radius, init    TP
# 903                                 ADV EFF ANTINFCT NEC/NOS    TP
# 543                                  OPEN WND KNEE/LEG/ANKLE    TP
# 803                                      Anemia, unspecified    TP
# 53                                       Anemia, unspecified    TP
# 883                                                   Nausea    TP
# 633                                          Epigastric pain    TP
# 213        Other psychoactive substance abuse, uncomplicated    TP
# 643                       LONG-TERM (CURRENT) USE OF INSULIN    TP
# 313                                        ANXIETY STATE NOS    TP
# 483                       Long term (current) use of aspirin    TP
# 443                                       HYPOTHYROIDISM NOS    TP
# 503           Type 1 diabetes mellitus without complications    TP
# 893                                 TRANS CEREB ISCHEMIA NOS    TP
# 123                       CAD UNSPEC VESSEL, NATIVE OR GRAFT    TP
# 353                       CAD UNSPEC VESSEL, NATIVE OR GRAFT    TP
# 373                                              Cholangitis    TP
# 513                Long term (current) use of anticoagulants    TP
# 393                                  HX-PROSTATIC MALIGNANCY    TP
# 523                    Contact with knife, initial encounter    TP
#
#                                                                                                                                                                      data_gpt  \
# 623                                  [fracture of lower end of left radius, lower end of left radius, left radius fracture, radius fracture, radius injury, injury of radius]
# 903                                                                                                       [antibiotic adverse effects, antoinfection effects, antoinfection.]
# 543                                                                                                        [open wound knee, leg, ankle, open wound, wound, knee, leg, ankle]
# 803                                                                                                                                              [anemia unspecified, anemia]
# 53                                                                                                                                               [anemia unspecified, anemia]
# 883                                                                                                                                                                  [nausea]
# 633                                                                                                                                                   [epigastric pain, pain]
# 213                                                                                                      [psychoactive substance abuse, substance abuse, psychoactive, abuse]
# 643                                                                                   [long term (current) use of insulin, long term use of insulin, use of insulin, insulin]
# 313                                                                                                                               [anxiety state nos, anxiety state, anxiety]
# 483                                                                      [long term (current) use of aspirin, long term use of aspirin, use of aspirin, aspirin use, aspirin]
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [0.88500524]
# 123                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [0.81974316, 0.8853638]
# 353                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [0.64495957, 0.6406947, 0.6373169, 0.5099533, 0.5116238, 0.5452402, 0.660881, 0.64695805, 0.6601094, 0.53083664, 0.6859967, 0.6502591, 0.6574741, 0.55372715, 0.5458883, 0.5639825, 0.67872137, 0.6598948, 0.63353544, 0.56151706, 0.67396307, 0.6064066, 0.63307315, 0.55941224, 0.5563161, 0.5757211, 0.7155131, 0.6889931, 0.6508722, 0.5676482, 0.81974316, 0.8853638]
# 373                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [0.80351293, 0.69348204, 0.8884053]
# 513                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [0.66212255, 0.65700114, 0.6775501, 0.66837573, 0.89710194]
# 393                                                                                                                                                                                                                                                                                                                                                                                                               [0.6648952, 0.7169694, 0.74155426, 0.6481963, 0.7441737, 0.68950903, 0.72964513, 0.6987754, 0.6807764, 0.7342527, 0.689253, 0.8230526, 0.8017421, 0.7515366, 0.79301447, 0.76799905, 0.8122309, 0.7369691, 0.8071877, 0.75010777, 0.73663527, 0.7390665, 0.7191513, 0.8310231, 0.7208358, 0.70257056, 0.765158, 0.6801517, 0.76172364, 0.7161688, 0.7517519, 0.7291411, 0.66574067, 0.7714159, 0.7249857, 0.75127167, 0.8979237]
# 523                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [0.8989233]
#
#      last_score
# 623    0.851440
# 903    0.854875
# 543    0.856961
# 803    0.857635
# 53     0.858305
# 883    0.858819
# 633    0.859007
# 213    0.861049
# 643    0.871046
# 313    0.874590
# 483    0.878723
# 443    0.879064
# 503    0.882662
# 893    0.885005
# 123    0.885364
# 353    0.885364
# 373    0.888405
# 513    0.897102
# 393    0.897924
# 523    0.898923

# %% [markdown]
# # Numerical-Question Evaluation (like bp: 162 / 80):

# %%
#classified_df_numerical = classified_df.copy()
classified_df_numerical =df_filled.copy()
classified_df_numerical.head(10)
# Out:
#    json_i                       _id             question  \
# 0       0  669933e4afbfd9c3c2d8efd0       chiefcomplaint
# 1       0  669933e4afbfd9c3c2d8efd0  medication_reported
# 2       0  669933e4afbfd9c3c2d8efd0     medication_pyxis
# 3       0  669933e4afbfd9c3c2d8efd0            diagnosis
# 4       0  669933e4afbfd9c3c2d8efd0                   bp
# 5       0  669933e4afbfd9c3c2d8efd0            heartrate
# 6       0  669933e4afbfd9c3c2d8efd0         o2sat_triage
# 7       0  669933e4afbfd9c3c2d8efd0             resprate
# 8       0  669933e4afbfd9c3c2d8efd0          temperature
# 9       0  669933e4afbfd9c3c2d8efd0          pain_triage
#
#                                                                                                                                                                                                                                                                                                                                                                                                   answer  \
# 0                                                  - Lower back pain (persisting for a few weeks)\n- Knee pain (persisting for a few weeks, sharp and comes and goes, getting worse over time)\n- Headache (constant, dull ache behind the eyes, started this morning)\n- Trouble sleeping due to pain\n- Affecting mood and energy levels\n- Allergic to bees (not related to current symptoms)  END OF
# 1  1. Acetaminophen 325mg TAB\n2. OxyContin (Oxycodone)\n3. Two 10mg tablets of an unknown medication (assumed to be a pain medication, possibly a generic or brand name of Oxycodone) taken in the morning.\n-------\nPlease extract every single pharmaceuticals, drugs and medications that the patient says he has taken or is taking as a list, like: Aspirin 1 tablet; Paracetamol; Antihistamine!
# 2                                              Acetaminophen, OxyContin\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single pharmaceuticals, drugs, medications that the patient is taking or has taken prior to the ambulance crew's intervention as a csv-list of only names/labels, like: Aspirin x mg; Paracetamol; antihistamine!
# 3                                                                                                                                                              1. Radiculopathy in the lumbar region\n2. Lower back pain\n3. Knee pain\n4. Headache\n5. Severe pain (back, 7 out of 10)\n6. Pain in the lumbar region\n7. Possible underlying medical condition for the symptoms (not specified)  END OF
# 4                                                                                                                                                                                                                                                                                                                                                                             165 over 103; 165 over 105
# 5                                                                                                                                             73; 74\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single'respiration rate' readings, pulse values that are in the text snippets as a csv-list of numerical values, like: 90; 100; 100!
# 6                                                                                                                                                                                                                                               97%, 97%\n\nPlease extract every single blood pressure reading that are in the text snippets as a list of numerical values, like: 90/60; 120/80; 100/50!
# 7                                                                                                                                                                                                                                                                                                                                                                                            15; 18; 18!
# 8                                                                                                                                                                   99.9; 99.9\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single heart rate readings that are in the text snippets as a list of numerical values, like: 98; 100; 37!
# 9                                                                                                                                                                                            0, 7, 7, 10\n-------\nGiven the context information and not prior knowledge answer always concisely.\nPlease extract every single medication that is mentioned in the conversation, like: Aspirin; Tylenol!
#
#                                      data Class
# 0  Lower back pain, L Knee pain, Headache
# 1                   oxycodone [OxyContin]
# 2                 Acetaminophen 325mg TAB
# 3            Radiculopathy, lumbar region
# 4        triage: 165 105; vitals: 165 103
# 5                triage: 74; vitals: 73.0
# 6                triage: 97; vitals: 97.0
# 7                  triage: 15; vitals: 18
# 8              triage: 99.9; vitals: 99.9
# 9                               triage: 7

# %%
# Questions of interest
numerical_questions = [
    "bp",
    "heartrate",
    "o2sat_triage",
    "resprate",
    "temperature",
    "pain_triage"
]

# %%
import json

def save_numerical_metric(metrics, file_name='numerical_metrics.json'):
    """
    Saves the provided metrics dictionary into a JSON file.

    Args:
    metrics (dict): The metrics dictionary containing tp, fp, fn, precision, recall, f1_score, instances.
    file_name (str): The name of the file to save the JSON data. Default is 'numerical_metrics.json'.
    """
    # Convert the metrics dictionary to a JSON string
    metrics_json = json.dumps(metrics, indent=4)
    
    # Write the JSON string to a file with the specified or dynamically generated name
    with open(file_name, 'w') as file:
        file.write(metrics_json)
    
    print(f"Numerical metrics saved to {file_name}")

# %%
import re

numerical_questions = [
    "bp",
    "heartrate",
    "o2sat_triage",
    "resprate",
    "temperature",
    "pain_triage"
]

def classify_numerical_data(df_numerical):
    tp, fp, fn = 0, 0, 0
    instances = 0
    classifications = []

    def is_match(data_value, answer):
        if data_value % 1 == 0:
            pattern = r'\b{}\b'.format(int(data_value))
            return re.search(pattern, answer) is not None
        else:
            patterns = [
                r'\b{}\b'.format(int(data_value)),
                r'\b{}\b'.format(round(data_value)),
                r'\b{}\b'.format(round(data_value - 0.5)),
                r'\b{}\b'.format(round(data_value + 0.5))
            ]
            for pattern in patterns:
                if re.search(pattern, answer):
                    return True
            return False

    for index, row in df_numerical.iterrows():
        data_values = re.findall(r'\d+\.?\d*', str(row['data']))
        if not data_values:
            continue
        
        data_values = list(map(float, data_values))
        instances += len(data_values)
        answer = str(row['answer'])
        row_classifications = []

        answer_values = re.findall(r'\d+\.?\d*', answer)
        if not answer_values:
            fn += len(data_values)
            row_classifications.extend(["FN"] * len(data_values))
        else:
            for data_value in data_values:
                if is_match(data_value, answer):
                    tp += 1
                    row_classifications.append("TP")
                else:
                    fp += 1
                    row_classifications.append("FP")

        classifications.append(row_classifications)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    df_numerical_classified = df_numerical.copy()
    df_numerical_classified['Class'] = ["; ".join(cls) for cls in classifications]

    cols = df_numerical_classified.columns.tolist()
    data_index = cols.index('data')
    cols.insert(data_index + 1, cols.pop(cols.index('Class')))
    df_numerical_classified = df_numerical_classified[cols]

    metrics = {
        'tp': tp,
        'fp': fp,
        'fn': fn,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'instances': instances
    }

    return metrics, df_numerical_classified


# Example usage
df_numerical = df_filled[df_filled['question'].isin(numerical_questions)]
metrics, df_numerical_classified = classify_numerical_data(df_numerical)
save_numerical_metric(metrics)
print(metrics)
#df_numerical_classified.head(50)
# Out:
# Numerical metrics saved to numerical_metrics.json
# {'tp': 1266, 'fp': 21, 'fn': 0, 'precision': 0.9836829836829837, 'recall': 1.0, 'f1_score': 0.9917743830787309, 'instances': 1287}

# %%
# This one if df stems from first nominal classification

#classified_df_numerical = classified_df_numerical[classified_df_numerical['question'].isin(numerical_questions)]
#df_numerical_classified = classified_df_numerical
#metrics, classified_df_numerical = classify_numerical_data(classified_df_numerical)

# %%
df_numerical_classified.head(10)

# %% [raw]
# # Save to CSV or handle the DataFrame as needed
# classified_df_numerical.to_csv('classified_df_numerical-de.csv', index=False)

# %%
import pandas as pd
from datetime import datetime
# Get current date
current_date = datetime.now().strftime("%Y-%m-%d")

# Create file name with date
file_name = f"classified_df_numerical-{current_date}-de.csv"

# Save dataframe to CSV
classified_df_numerical.to_csv(file_name, index=False)

# %% [markdown]
# ## Save Nominal Total as CSV for savekeeping

# %%
df_nominal_total = pd.concat([df_nominal_drugs_classified, df_nominal_conditions_classified], ignore_index=True)

# %%
df_nominal_total.info()

# %%
# Get current date
current_date = datetime.now().strftime("%Y-%m-%d")

# Create file name with date
file_name = f"df_nominal_total-{current_date}.csv"

# Save dataframe to CSV
df_nominal_total.to_csv(file_name, index=False)

# %%
def calculate_metrics(df):
    tp = sum(df['Class'] == "TP")
    fp = sum(df['Class'] == "FP")
    fn = sum(df['Class'] == "FN")
    
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    metrics = {
        'tp': tp,
        'fp': fp,
        'fn': fn,
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }
    
    return metrics

# Calculate metrics for the combined DataFrame
metrics_nominal_total = calculate_metrics(df_nominal_total)

# Print the metrics
metrics_nominal_total

# %% [markdown]
# ## Exctract sample of badest

# %%
sample_of_BAD

# %%
import pandas as pd
# Filter the DataFrame to include only rows with Class 'FN' and 'FP'
sample_of_BAD = classified_df_lastscored[classified_df_lastscored['Class'].isin(['FN', 'FP'])]

# Sort the filtered DataFrame by 'last_score' in ascending order
sample_of_BAD = sample_of_BAD.sort_values(by='last_score', ascending=True)

# Medication got 50% loss of precision from english to deutsch, und bei medication_pyxis waren es 30%
# Ich will jetzt die schlechste

df_diagnosis_halfbad = sample_of_BAD[sample_of_BAD['question'] == 'diagnosis']
df_medication_pyxis_thirdbad = sample_of_BAD[sample_of_BAD['question'] == 'medication_pyxis']


# Select the first 10 rows from bad ones as a sample
sample_df_diagnosis_halfbad = df_diagnosis_halfbad.iloc[1:11]
sample_df_medication_pyxis_thirdbad = df_medication_pyxis_thirdbad.head(10)

# Save the sample DataFrames as CSV files
sample_df_diagnosis_halfbad.to_csv('sample_df_diagnosis_halfbad.csv', index=False)
sample_df_medication_pyxis_thirdbad.to_csv('sample_df_medication_pyxis_thirdbad.csv', index=False)


# Also for numerical since they where also 1/3 more bad than english
sample_df_numerical_thirdbad = classified_df_numerical[~classified_df_numerical['Class'].str.contains('TP')]
sample_df_numerical_thirdbad.head(10)
sample_df_numerical_thirdbad.to_csv('sample_df_numerical_thirdbad.csv', index=False)

# %%
# now get some good ones too
import pandas as pd

# Assuming sample_of_BAD and classified_df_numerical are already created from the previous steps

# Select the good ones for nominal data (Class == 'TP') and sort by 'last_score' in descending order
sample_of_GOOD = classified_df_lastscored[classified_df_lastscored['Class'] == 'TP'].sort_values(by='last_score', ascending=False)

# Filter for 'diagnosis' and 'medication_pyxis' for the good ones
df_diagnosis_good = sample_of_GOOD[sample_of_GOOD['question'] == 'diagnosis']
df_medication_pyxis_good = sample_of_GOOD[sample_of_GOOD['question'] == 'medication_pyxis']

# Select the first 10 rows from the good ones as a sample
sample_df_diagnosis_good = df_diagnosis_good.head(10)
sample_df_medication_pyxis_good = df_medication_pyxis_good.head(10)

# Save the sample DataFrames as CSV files
sample_df_diagnosis_good.to_csv('sample_df_diagnosis_good.csv', index=False)
sample_df_medication_pyxis_good.to_csv('sample_df_medication_pyxis_good.csv', index=False)

# For numerical data, pick rows that have all 'TP'
sample_df_numerical_good = classified_df_numerical[classified_df_numerical['Class'].apply(lambda x: set(x.split('; ')) == {'TP'})]

# Select the first 10 rows from the good numerical ones
sample_df_numerical_good = sample_df_numerical_good.head(10)

# Save the numerical good sample as a CSV file
sample_df_numerical_good.to_csv('sample_df_numerical_good.csv', index=False)

# %%
import pandas as pd

# Load the CSV files into DataFrames
sample_df_diagnosis_halfbad = pd.read_csv('sample_df_diagnosis_halfbad.csv')
sample_df_medication_pyxis_thirdbad = pd.read_csv('sample_df_medication_pyxis_thirdbad.csv')
sample_df_numerical_thirdbad = pd.read_csv('sample_df_numerical_thirdbad.csv')

# Extract the unique _id values from each DataFrame
ids_diagnosis = set(sample_df_diagnosis_halfbad['_id'].unique())
ids_medication_pyxis = set(sample_df_medication_pyxis_thirdbad['_id'].unique())
ids_numerical = set(sample_df_numerical_thirdbad['_id'].unique())

# Find the intersection of _id values that are present in all three DataFrames
common_ids = ids_diagnosis & ids_medication_pyxis & ids_numerical

# If fewer than 10 unique _id values are found, add additional unique _id values
if len(common_ids) < 10:
    all_ids = ids_diagnosis | ids_medication_pyxis | ids_numerical
    additional_ids_needed = 10 - len(common_ids)
    additional_ids = all_ids - common_ids
    additional_ids = list(additional_ids)[:additional_ids_needed]
    common_ids.update(additional_ids)

# Convert the set of _id values to a list
common_ids_list = list(common_ids)[:10]

# Convert the list to a DataFrame
common_ids_df = pd.DataFrame(common_ids_list, columns=['_id'])
print(common_ids_df)

# Save the DataFrame as a CSV file
common_ids_df.to_csv('common_ids_list_bad-NLP-EXPANDED-prammed.csv', index=False)

# Display a message indicating the file has been saved
print("common_ids_list_bad.csv has been saved-NLP-EXPANDED_PRAMMED.")

common_ids_df.to_csv('common_ids_list_bad-NLP-EXPANDED-prammed.csv', index=False)

# %%
import pandas as pd

# Load the CSV files into DataFrames
sample_df_diagnosis_good = pd.read_csv('sample_df_diagnosis_good.csv')
sample_df_medication_pyxis_good = pd.read_csv('sample_df_medication_pyxis_good.csv')
sample_df_numerical_good = pd.read_csv('sample_df_numerical_good.csv')

# Extract the unique _id values from each DataFrame
ids_diagnosis_good = set(sample_df_diagnosis_good['_id'].unique())
ids_medication_pyxis_good = set(sample_df_medication_pyxis_good['_id'].unique())
ids_numerical_good = set(sample_df_numerical_good['_id'].unique())

# Find the intersection of _id values that are present in all three DataFrames
common_ids_good = ids_diagnosis_good & ids_medication_pyxis_good & ids_numerical_good

# If fewer than 10 unique _id values are found, add additional unique _id values
if len(common_ids_good) < 10:
    all_ids_good = ids_diagnosis_good | ids_medication_pyxis_good | ids_numerical_good
    additional_ids_needed_good = 10 - len(common_ids_good)
    additional_ids_good = all_ids_good - common_ids_good
    additional_ids_good = list(additional_ids_good)[:additional_ids_needed_good]
    common_ids_good.update(additional_ids_good)

# Convert the set of _id values to a list
common_ids_list_good = list(common_ids_good)[:10]

# Convert the list to a DataFrame
common_ids_df_good = pd.DataFrame(common_ids_list_good, columns=['_id'])

# Save the DataFrame as a CSV file
common_ids_df_good.to_csv('common_ids_list_good-NLP-EXPANDED-prammed.csv', index=False)

# Display a message indicating the file has been saved
print("common_ids_list_good.csv has been saved-NLP-EXPANDED_PRAMMED.")
