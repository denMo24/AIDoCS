# %%
import os
from pymongo import MongoClient
import openai
import tiktoken
from dotenv import load_dotenv

# Load environment variables from a specified .env file for secure API key storage
env_path = '/home/msd4/aidocsMosi/openAI_Token.env'
load_dotenv(dotenv_path=env_path)

# Retrieve the OpenAI API key from the environment variables
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
if not OPENAI_API_KEY:
    # Raise an error if the API key is not found, to prevent API calls without authentication
    raise ValueError("No API key found. Please set your OPENAI_API_KEY in the .env file.")

# %%
# MongoDB client setup
client = MongoClient('mongodb://localhost:27017/')
db = client['MIMIC-IV']

# source_collection = db['NLP-EXP-pram-sampled']
source_collection = db['NLP-EXPANDED-prammed-2']
target_collection = db['NLP-EXPANDED-prammed-postprocessed_translation']

# %%
# OpenAI API setup
openai.api_key = OPENAI_API_KEY
MODEL = "gpt-4o"
MAX_TOKENS = 4096
DESIRED_OUTPUT_TOKENS = 2000
MAX_INPUT_TOKENS = MAX_TOKENS - DESIRED_OUTPUT_TOKENS
tokenizer = tiktoken.get_encoding("cl100k_base")

# %%
def count_tokens(text):
    return len(tokenizer.encode(text))

def split_text(text, max_chunk_size):
    words = text.split()
    chunks = []
    current_chunk = []
    current_chunk_size = 0

    for word in words:
        word_tokens = count_tokens(word)
        if current_chunk_size + word_tokens <= max_chunk_size:
            current_chunk.append(word)
            current_chunk_size += word_tokens
        else:
            chunks.append(" ".join(current_chunk))
            current_chunk = [word]
            current_chunk_size = word_tokens

    if current_chunk:
        chunks.append(" ".join(current_chunk))

    return chunks

def translate_chunk(chunk, source_language="German", target_language="English"):
    # prompt_template = f"Translate the following {source_language} text to {target_language}:\n\n{chunk}"
    prompt_template = f"Translate the following {source_language} text to {target_language}, and keep the numerical values unchanged:\n\n{chunk}"

    completion = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "You are a helpful assistant for translating medical dialogue text!"},
            {"role": "user", "content": prompt_template}
        ],
        max_tokens=DESIRED_OUTPUT_TOKENS,
        temperature=0.3,
    )

    translated_dialogue = completion.choices[0].message.content

    return translated_dialogue



def translate_text(text):
    chunks = split_text(text, MAX_INPUT_TOKENS)
    translated_chunks = [translate_chunk(chunk) for chunk in chunks]
    return " ".join(translated_chunks)

def process_documents(start_index=None, end_index=None, range_type='range'):
    if range_type == 'all':
        documents = source_collection.find()
    else:
        if start_index is None or end_index is None:
            raise ValueError("Start and end indices must be provided for range processing.")
        documents = source_collection.find().skip(start_index).limit(end_index - start_index + 1)

    for doc in documents:
        print('doc-text is being translated')
        original_text = doc.get("final_dialogue", "")
        if original_text:  # Proceed only if there's text to translate
            translated_text = translate_text(original_text)
            doc["final_to_english"] = translated_text
            # Remove the '_id' field to avoid DuplicateKeyError
            doc.pop("_id", None)
            target_collection.insert_one(doc)

# %%
#process_documents(start_index=1, end_index=99, range_type='range')
#process_documents(range_type='all')

process_documents(start_index=102, end_index=127, range_type='range')
process_documents(start_index=101, end_index=101, range_type='range')

# %% [markdown]
# # First Test: single text

# %% [raw]
# # Import necessary libraries and modules
# from dotenv import load_dotenv
# import os
# from openai import OpenAI
# import pandas as pd
# from pymongo import MongoClient
# from bson.objectid import ObjectId
# import tiktoken

# %% [raw]
# # Load environment variables from a specified .env file for secure API key storage
# env_path = '/home/msd4/aidocsMosi/openAI_Token.env'
# load_dotenv(dotenv_path=env_path)
#
# # Retrieve the OpenAI API key from the environment variables
# OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
# if not OPENAI_API_KEY:
#     # Raise an error if the API key is not found, to prevent API calls without authentication
#     raise ValueError("No API key found. Please set your OPENAI_API_KEY in the .env file.")
#
# # Initialize the OpenAI client with the retrieved API key
# client = OpenAI(api_key=OPENAI_API_KEY)
#
# # Define constants
# MODEL = "gpt-4o"
# MAX_TOKENS = 4096
# DESIRED_OUTPUT_TOKENS = 2000 # Adjust based on expected output length
# MAX_INPUT_TOKENS = MAX_TOKENS - DESIRED_OUTPUT_TOKENS

# %% [raw]
# # MongoDB client setup
# client = MongoClient('mongodb://localhost:27017/')
# db = client['MIMIC-IV']
#
#
# #expanded_collection = db['NLP-EXPANDED-prammed']
# #target_collection = db['NLP-EXP-pram-sampled']
#
# source_collection = db['NLP-EXP-pram-sampled'] # samples that used on new adjusted expansiongeneration with openai
# target_collection = db['NLP-EXPANDED-prammed-postprocessed_translation'] #

# %% [raw]
# # Initialize tokenizer with a common encoding
# tokenizer = tiktoken.get_encoding("cl100k_base") # at the moment for gpt-4o isnt available so use that general one.
#
# def count_tokens(text):
#     """Use tiktoken to count tokens more accurately."""
#     return len(tokenizer.encode(text))
#
# def split_text(text, max_chunk_size):
#     """Split text into chunks of max_chunk_size tokens."""
#     words = text.split()
#     chunks = []
#     current_chunk = []
#     current_chunk_size = 0
#
#     for word in words:
#         word_tokens = count_tokens(word)
#         if current_chunk_size + word_tokens <= max_chunk_size:
#             current_chunk.append(word)
#             current_chunk_size += word_tokens
#         else:
#             chunks.append(" ".join(current_chunk))
#             current_chunk = [word]
#             current_chunk_size = word_tokens
#
#     if current_chunk:
#         chunks.append(" ".join(current_chunk))
#
#     return chunks
#
# def translate_chunk(chunk, source_language="German", target_language="English"):
#     """Translate a text chunk from source_language to target_language."""
#     prompt_template = f"Translate the following {source_language} text to {target_language}:\n\n{chunk}"
#
#     completion = openai.ChatCompletion.create(
#         model=MODEL,
#         messages=[
#             {"role": "system", "content": "You are a helpful assistant for translating medical dialogue text!"},
#             {"role": "user", "content": prompt_template}
#         ],
#         max_tokens=DESIRED_OUTPUT_TOKENS,
#         temperature=0.3,
#     )
#
#     return completion.choices[0].message["content"].strip()
#
# def translate_text(text):
#     """Translate a large text by chunking and then concatenating the results."""
#     chunks = split_text(text, MAX_INPUT_TOKENS)
#     translated_chunks = [translate_chunk(chunk) for chunk in chunks]
#     return " ".join(translated_chunks)
#
#
# def test__print_single_chunks_info(chunks):
#     """Print the count of chunks, the size of each chunk in words, and the token count of each chunk."""
#     for i, chunk in enumerate(chunks):
#         word_count = len(chunk.split())
#         token_count = count_tokens(chunk)
#         print(f"Chunk {i + 1}:")
#         print(f"  Word Count: {word_count}")
#         print(f"  Token Count: {token_count}")
#         print(f"  Text: {chunk}")
#         print()
#         input("Press Enter to see the next chunk...")

# %% [raw]
# source_language= "German"
# target_language= "English"
# input_dialogue = ""
# output_dialogue = ""
# max_tokens = 4000
# temperature = 0.3
#
# # Prompt template used in API-call
# prompt_template  = f""" Translate the following {source_language} text to {target_language}:\n\n{german_text} """
#
# # API CALL
# completion = client.chat.completions.create(
#   model=MODEL,
#   messages=[
#     {"role": "system", "content": "You are a helpful assistant for translating medical dialogue text!"},
#     {"role": "user", "content": prompt_template}],
#      max_tokens=max_tokens,
#     temperature=temperature,
# )
# # API-Response
# #translated_dialogue = completion.choices[0].message.content

# %% [markdown]
# # Snippets

# %% [raw]
# source_language= "German"
# target_language= "English"
# input_dialogue = ""
# output_dialogue = ""
# max_tokens = 4000
# temperature = 0.3
#
# # Prompt template used in API-call
# prompt_template  = f""" Translate the following {source_language} text to {target_language}:\n\n{german_text} """
#
# # API CALL
# completion = client.chat.completions.create(
#   model=MODEL,
#   messages=[
#     {"role": "system", "content": "You are a helpful assistant for translating medical dialogue text!"},
#     {"role": "user", "content": prompt_template}],
#      max_tokens=max_tokens,
#     temperature=temperature,
# )
# # API-Response
# translated_dialogue = completion.choices[0].message.content

# %%
#testing
#original_token_count = count_tokens(german_text)
#print(f"Original Token Count: {original_token_count}\n")

#chunks = split_text(german_text, MAX_INPUT_TOKENS)
#print_chunks_info(chunks)

# %% [raw]
# german_text = f"""
# Sanitäter Jens Müller: "Anna, wir haben einen männlichen Patienten, Herr Smith, in seinen späten 40ern mit rektalen Blutungen. Er ist allein zu Hause, seine Frau ist verreist und die Kinder sind bei der Mutter."
#
# Notfallsanitäterin Anna Schmidt: "Verstanden, Jens. Keine Hinweise auf ein Gefährdungspotential am Einsatzort, richtig?"
#
# Sanitäter Jens Müller: "Richtig, Anna. Der Einsatzort scheint sicher zu sein."
# Jens: Herr Smith, mein Name ist Jens und das ist meine Kollegin Anna. Wir sind vom Rettungsdienst. Können Sie uns sagen, was passiert ist?
#
# Herr Smith: Ich habe Blut im Stuhl bemerkt und fühle mich schwach.
#
# Anna: Verstehen Sie, Herr Smith. Wir werden Sie jetzt untersuchen und Ihre Vitalzeichen überprüfen.
#
# Jens: Anna, ich übernehme die Atemwege und Atmung.
#
# Anna: In Ordnung, Jens. Ich kümmere mich um den Kreislauf und das neurologische Status.
#
# Jens: Herr Smith, Ihre Atemwege sind frei und es gibt keine Anzeichen von Atemnot.
#
# Anna: Ihr Kreislauf scheint stabil zu sein, Herr Smith. Sie zeigen keine Anzeichen für akute Kreislaufprobleme.
#
# Jens: Können Sie uns sagen, ob Sie sich irgendwo verletzt haben, Herr Smith?
#
# Herr Smith: Nein, ich habe keine Verletzungen.
#
# Anna: Herr Smith, Sie sind neurologisch unauffällig. Das ist ein gutes Zeichen.
#
# Jens: Wir müssen Sie jetzt sicher in den Rettungswagen bringen, Herr Smith.
#
# Anna: Wir werden Sie gut versorgen, Herr Smith. Sie sind in sicheren Händen.
# Jens: "Herr Smith, Sie haben uns erzählt, dass Sie Blut im Stuhl bemerkt haben. Haben Sie irgendwelche Medikamente eingenommen?"
#
# Herr Smith: "Nein, ich habe keine Medikamente eingenommen."
#
# Anna: "Haben Sie noch andere Symptome bemerkt, Herr Smith? Schmerzen irgendwo oder vielleicht Übelkeit?"
#
# Herr Smith: "Nein, keine Schmerzen und auch keine Übelkeit. Nur das Blut im Stuhl, das hat mich beunruhigt."
#
# Jens: "Das ist verständlich, Herr Smith. Wir werden Sie jetzt in den Rettungswagen bringen und dort weitere Untersuchungen durchführen. Sie sind in guten Händen."
#
# Anna: "Jens, ich werde während der Fahrt den Kreislauf und den neurologischen Status von Herrn Smith weiter überwachen."
#
# Jens: "Gut, Anna. Ich kümmere mich um die Atemwege und die Atmung. Herr Smith, wir werden Sie gut versorgen."
#
# Herr Smith: "Danke, ich vertraue Ihnen."
# Jens: "Herr Smith, wir werden jetzt Ihre Vitalzeichen überprüfen. Das ist ein ganz normaler Vorgang."
#
# Herr Smith: "In Ordnung."
#
# Anna: "Die Herzfrequenz liegt bei 97, die Atemfrequenz bei 18, der Blutdruck bei 113/83 und die Sauerstoffsättigung bei 99%."
#
# Jens: "Okay, danke Anna. Herr Smith, Ihre Werte sehen gut aus. Wir korrigieren die Herzfrequenz auf 86 und die Atemfrequenz auf 16. Ihr Blutdruck ist etwas gesunken auf 97/69, aber das ist noch im normalen Bereich."
#
# Herr Smith: "Ich fühle mich auch nicht schlecht. Nur ein bisschen Bauchschmerzen habe ich."
#
# Anna: "Wo genau haben Sie die Schmerzen, Herr Smith?"
#
# Herr Smith: "So mittig, würde ich sagen."
#
# Jens: "Okay, wir behalten das im Auge. Es könnte mit dem Blut im Stuhl zusammenhängen, aber wir können das erst im Krankenhaus genauer abklären."
#
# Anna: "Herr Smith, wir sind gleich im Krankenhaus. Dort wird man Sie weiter untersuchen und herausfinden, was die Ursache für das Blut im Stuhl ist."
#
# Herr Smith: "Ich verstehe. Danke für Ihre Hilfe."
# Jens: Anna, ich denke, wir sollten Ondansetron verabreichen, um die Bauchschmerzen zu lindern.
#
# Anna: Ja, das klingt nach einer guten Idee. Herr Smith, wir werden Ihnen jetzt ein Medikament geben, das Ihre Bauchschmerzen lindern sollte.
#
# Herr Smith: Okay, danke.
#
# Jens: Anna, könnten Sie bitte die Verabreichung des Ondansetrons vorbereiten?
#
# Anna: Ja, mache ich. Herr Smith, ich werde Ihnen jetzt das Medikament geben.
#
# Herr Smith: In Ordnung.
#
# Jens: Herr Smith, wie fühlen Sie sich jetzt? Hat das Medikament geholfen?
#
# Herr Smith: Ja, die Schmerzen sind etwas besser. Aber ich mache mir Sorgen wegen dem Blut.
#
# Jens: Das ist verständlich, Herr Smith. Wir werden das im Krankenhaus weiter abklären. Es ist wichtig, dass wir herausfinden, woher das Blut kommt.
#
# Anna: Jens, ich denke, wir sollten Herrn Smith während des Transports weiterhin überwachen.
#
# Jens: Ja, das sehe ich genauso. Wir müssen sicherstellen, dass seine Vitalzeichen stabil bleiben.
# Jens: "Anna, wie sehen die Vitalzeichen aus?"
#
# Anna: "Die Vitalzeichen sind stabil, Jens. Der Puls ist regelmäßig, die Atmung ist ruhig und die Sauerstoffsättigung ist gut."
#
# Jens: "Sehr gut, Anna. Herr Smith, wie fühlen Sie sich jetzt? Sind die Bauchschmerzen besser geworden?"
#
# Herr Smith: "Ja, die Schmerzen sind etwas besser. Aber ich mache mir Sorgen wegen dem Blut..."
#
# Jens: "Das ist verständlich, Herr Smith. Wir werden im Krankenhaus weitere Untersuchungen durchführen, um herauszufinden, woher das Blut kommt. Versuchen Sie, ruhig zu bleiben."
#
# Anna: "Jens, ich denke, wir sollten Herrn Smith während des Transports weiterhin engmaschig überwachen."
#
# Jens: "Ja, das sehe ich genauso, Anna. Wir müssen sicherstellen, dass seine Vitalzeichen stabil bleiben."
#
# Herr Smith: "Ich verstehe... Ich vertraue Ihnen."
#
# Jens: "Das ist gut zu hören, Herr Smith. Wir tun unser Bestes, um Ihnen zu helfen."
# Jens: "Anna, ich denke, wir sollten Herrn Smith in die nächstgelegene Klinik mit einer spezialisierten Abteilung für Gastroenterologie bringen. Dort können sie den Blutverlust genauer untersuchen."
#
# Anna: "Ja, Jens, das klingt nach einer guten Entscheidung. Ich werde die Klinik informieren und den Transport vorbereiten."
#
# Jens: "Herr Smith, wir werden Sie jetzt in eine Klinik bringen, die spezialisiert auf Magen-Darm-Erkrankungen ist. Dort können sie den Blutverlust genauer untersuchen und behandeln."
#
# Herr Smith: "Das klingt gut. Ich vertraue Ihnen."
#
# Anna: "Herr Smith, wir werden Sie während des Transports engmaschig überwachen. Sollte sich Ihr Zustand verändern, können wir sofort reagieren."
#
# Jens: "Anna, bitte stelle sicher, dass alle Geräte für die Überwachung der Vitalzeichen ordnungsgemäß funktionieren und der IV-Zugang sicher sitzt."
#
# Anna: "Alles klar, Jens. Ich überprüfe die Geräte und den IV-Zugang."
#
# Jens: "Herr Smith, wir werden jetzt losfahren. Sie sind in guten Händen."
#
# Herr Smith: "Danke, ich fühle mich sicher mit Ihnen."
# Jens: "Anna, bitte stelle sicher, dass Herr Smith während des Transports stabil bleibt. Überwache seine Vitalzeichen engmaschig."
#
# Anna: "Verstanden, Jens. Ich werde seine Vitalzeichen im Auge behalten."
#
# Jens: "Herr Smith, wir bringen Sie jetzt in die Klinik. Sie sind in guten Händen."
#
# Herr Smith: "Danke, ich vertraue Ihnen."
#
# Anna: "Herr Smith, wir werden während der Fahrt Ihre Vitalzeichen überwachen. Sollte sich Ihr Zustand verändern, können wir sofort reagieren."
#
# Herr Smith: "Das beruhigt mich. Danke, Anna."
#
# Jens: "Anna, bitte überprüfe den IV-Zugang noch einmal, bevor wir losfahren."
#
# Anna: "Alles klar, Jens. Der IV-Zugang ist sicher und funktioniert einwandfrei."
#
# Jens: "Gut, dann können wir losfahren. Herr Smith, wir sind bereit. Sind Sie es auch?"
#
# Herr Smith: "Ja, ich bin bereit. Danke, dass Sie sich so gut um mich kümmern."
# Jens: "Anna, wie sieht es bei Herrn Smith aus? Sind die Vitalzeichen stabil?"
#
# Anna: "Ja, Jens. Die Vitalzeichen sind stabil. Der Puls ist regelmäßig und die Atmung ist ruhig."
#
# Jens: "Sehr gut, Anna. Bitte behalte das im Auge und informiere mich sofort über jede Änderung."
#
# Anna: "Verstanden, Jens. Ich behalte die Vitalzeichen im Blick."
#
# Herr Smith: "Geht es mir gut?"
#
# Anna: "Ja, Herr Smith. Ihre Vitalzeichen sind stabil. Wir überwachen Sie kontinuierlich während der Fahrt."
#
# Herr Smith: "Danke, Anna. Ich fühle mich in guten Händen."
#
# Jens: "Das ist unser Job, Herr Smith. Wir sind für Sie da."
#
# Anna: "Jens, der IV-Zugang ist immer noch sicher und funktioniert einwandfrei."
#
# Jens: "Gut, Anna. Bitte überprüfe ihn regelmäßig während der Fahrt."
#
# Anna: "Mache ich, Jens. Herr Smith, wir sind gleich in der Klinik. Alles ist unter Kontrolle."
#
# Herr Smith: "Danke, Anna. Ich vertraue euch."
# Jens: Anna, wie sieht es aus? Wie sind die Vitalzeichen von Herrn Smith?
#
# Anna: Jens, der Puls ist stabil bei 80 Schlägen pro Minute, die Atmung ist ruhig und regelmäßig. Der Blutdruck liegt bei 120/80 mmHg.
#
# Jens: Gut, Anna. Wie sieht es mit dem IV-Zugang aus?
#
# Anna: Der IV-Zugang ist sicher und funktionsfähig, Jens. Die Infusion läuft.
#
# Jens: Sehr gut, Anna. Bitte überprüfe die Vitalzeichen und den IV-Zugang regelmäßig während der Fahrt.
#
# Anna: Verstanden, Jens. Ich behalte alles im Auge.
#
# Jens: Herr Smith, wie fühlen Sie sich? Haben Sie Schmerzen oder Unwohlsein?
#
# Herr Smith: Nein, ich fühle mich eigentlich ganz gut. Ich vertraue auf Ihre medizinische Versorgung.
#
# Jens: Das ist gut zu hören, Herr Smith. Wir sind für Sie da. Anna wird Ihre Vitalzeichen und den IV-Zugang regelmäßig überprüfen.
#
# Anna: Herr Smith, ich werde jetzt Ihre Vitalzeichen überprüfen und sicherstellen, dass der IV-Zugang ordnungsgemäß funktioniert.
#
# Herr Smith: Danke, Anna. Ich fühle mich in guten Händen.
# Jens: "Leitstelle, hier ist Rettungswagen 4. Wir haben einen Patienten mit Verdacht auf hämorrhagische Komplikation. Wir haben Ondansetron zur Schmerzlinderung verabreicht. Ankunft in der Klinik in etwa 15 Minuten."
#
# Leitstelle: "Verstanden, Rettungswagen 4. Wir bereiten ein Team für die Übernahme vor. Bitte halten Sie uns auf dem Laufenden."
#
# Jens: "Wird gemacht, Leitstelle. Danke."
#
# Anna: "Herr Smith, wir sind gleich in der Klinik. Dort wird ein Team auf Sie warten, um Sie weiter zu versorgen."
#
# Herr Smith: "Danke, Anna. Ich fühle mich in guten Händen."
#
# In der Klinik:
#
# Jens: "Guten Tag, wir haben hier Herrn Smith. Verdacht auf hämorrhagische Komplikation. Wir haben Ondansetron zur Schmerzlinderung verabreicht. Vitalzeichen sind stabil, IV-Zugang ist sicher und funktionsfähig."
#
# Klinikpersonal: "Danke für die Informationen. Wir übernehmen jetzt."
#
# Nach der Übergabe:
#
# Anna: "Jens, das war ein guter Einsatz. Ich denke, Herr Smith ist jetzt in guten Händen."
#
# Jens: "Ja, das denke ich auch. Lass uns zurückkehren und bereit für den nächsten Einsatz sein."
#
#
# """
